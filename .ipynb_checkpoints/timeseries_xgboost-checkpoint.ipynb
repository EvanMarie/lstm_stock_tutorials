# %% [markdown]
# <a name="top"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# # Time Series Forecasting with XGBoost
# <br>
# <font size = 5>
#
# | [Video One](https://youtu.be/vV12dGe_Fho)  |  [Video Two](https://youtu.be/z3ZnOW-S550) | </font>

# %%
from helpers import *
import_all()
from xgboost import XGBRegressor
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# <a name="data"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**The Data**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Importing Data**

# %%
data = pd.read_csv("energy_data/PJME_hourly.csv", index_col = "Datetime")
data.index = pd.to_datetime(data.index)
head_tail_horz(data, 5, "PJME", intraday=True)
# Out:
# <span style = 'display: block; width: 40.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>PJME						</text></font></b></style>
# <center><style type="text/css">
# #T_1d7c2 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_1d7c2" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1d7c2_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d7c2_level0_row0" class="row_heading level0 row0" >2002-12-31 01:00:00</th>
#       <td id="T_1d7c2_row0_col0" class="data row0 col0" >26,498.00</td>
#     </tr>
#     <tr>
#       <th id="T_1d7c2_level0_row1" class="row_heading level0 row1" >2002-12-31 02:00:00</th>
#       <td id="T_1d7c2_row1_col0" class="data row1 col0" >25,147.00</td>
#     </tr>
#     <tr>
#       <th id="T_1d7c2_level0_row2" class="row_heading level0 row2" >2002-12-31 03:00:00</th>
#       <td id="T_1d7c2_row2_col0" class="data row2 col0" >24,574.00</td>
#     </tr>
#     <tr>
#       <th id="T_1d7c2_level0_row3" class="row_heading level0 row3" >2002-12-31 04:00:00</th>
#       <td id="T_1d7c2_row3_col0" class="data row3 col0" >24,393.00</td>
#     </tr>
#     <tr>
#       <th id="T_1d7c2_level0_row4" class="row_heading level0 row4" >2002-12-31 05:00:00</th>
#       <td id="T_1d7c2_row4_col0" class="data row4 col0" >24,860.00</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_4a966 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_4a966" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a966_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a966_level0_row0" class="row_heading level0 row0" >2018-01-01 20:00:00</th>
#       <td id="T_4a966_row0_col0" class="data row0 col0" >44,284.00</td>
#     </tr>
#     <tr>
#       <th id="T_4a966_level0_row1" class="row_heading level0 row1" >2018-01-01 21:00:00</th>
#       <td id="T_4a966_row1_col0" class="data row1 col0" >43,751.00</td>
#     </tr>
#     <tr>
#       <th id="T_4a966_level0_row2" class="row_heading level0 row2" >2018-01-01 22:00:00</th>
#       <td id="T_4a966_row2_col0" class="data row2 col0" >42,402.00</td>
#     </tr>
#     <tr>
#       <th id="T_4a966_level0_row3" class="row_heading level0 row3" >2018-01-01 23:00:00</th>
#       <td id="T_4a966_row3_col0" class="data row3 col0" >40,164.00</td>
#     </tr>
#     <tr>
#       <th id="T_4a966_level0_row4" class="row_heading level0 row4" >2018-01-02 00:00:00</th>
#       <td id="T_4a966_row4_col0" class="data row4 col0" >38,608.00</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145366 entries, 2002-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   PJME_MW  145366 non-null  float64
# dtypes: float64(1)
# memory usage: 2.2 MB

# %%
data.shape
# Out:
# (145366, 1)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Initial Plotting**

# %%
colors = sns.color_palette('husl', 11)
colors
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8836443049112893, 0.5240073524369634, 0.19569304285113343),
#  (0.710130687316902, 0.6046852192663268, 0.19426060163712158),
#  (0.5432776721247529, 0.6540981095185215, 0.19324494273892204),
#  (0.19592059105779686, 0.6981620017487838, 0.3452219818913641),
#  (0.2067117296964458, 0.6829103404254792, 0.5829988925822328),
#  (0.21420912437215422, 0.6714963557258681, 0.6986206664203177),
#  (0.22537170008202412, 0.6531400148480775, 0.841007805313343),
#  (0.5596943802099308, 0.5764402169887779, 0.9583930713150347),
#  (0.8578978803740231, 0.44058452715322166, 0.957819659566579),
#  (0.9628653850704806, 0.4025928454059796, 0.7779310354076443)]

# %%
fig = plt.figure(facecolor = '#333333', figsize = (13,7));
ax = plt.axes();
ax.set_facecolor('#444444')
data.plot(style = '.', 
		  color = colors[9], 
		  ax = ax);
ax.grid()
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white'); plt.yticks(color='white');
plt.title('PJME Energy Use (Megawatts)', fontsize = 24, pad = 20, color = 'white');

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Looking at a Single Week of Data**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
data.iloc[(data.index > '01-01-2010') \
		  & (data.index < '01-08-2010')].plot(ax = ax, 
											  linewidth = 3,
											  color = colors[6])
ax.grid()
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Energy Usage: January 1 - 8, 2010', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <a name="outliers"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Removing Outlier Data**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Removing Outlier: the sudden dip in late 2012**

# %%
data.loc[data.PJME_MW == min(data.PJME_MW)]
# Out:
#                       PJME_MW
# Datetime
# 2012-10-30 04:00:00 14,544.00

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Investigating the month span centered on outlier data**

# %%
outlier_span = data.loc['2012-10-15' : '2012-11-15']

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
outlier_span.plot(ax = ax, 
				  linewidth = 3,
				  color = colors[6])
ax.grid()
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('One Month Centered on Outlier', fontsize = 24, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Investigating the day of the outlier**

# %%
outlier_day = data.loc['2012-10-29':'2012-10-30']

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
outlier_day.plot(ax = ax, 
				  linewidth = 3,
				  color = colors[6])
ax.grid()
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Day of Outlier', fontsize = 24, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Distribution of Energy Use Values**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
data['PJME_MW'].plot(kind = 'hist', bins = 250,
				  color = 'deeppink', edgecolor = 'white');
ax.grid()
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Distribution of Energy Use Values', fontsize = 24, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Investigating records where the value goes below histogram min**

# %%
minimals = data.query('PJME_MW < 18_500')

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
minimals.plot(style = '.', markersize = 25,
				  color = 'deeppink', ax = ax);
ax.grid()
ax.set_ylim(10000, 40000)
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Oulier Low Point', fontsize = 24, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Overwriting the dataframe eliminating records less than 18,500 & Saving as the DF**

# %%
df = data.query('PJME_MW > 18_500').copy()

# %% [markdown]
# <a name="features"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Feature Engineering**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Time Series DateTime Index Feature Creation**

# %%
def featurize_datetime_index(df, daytime = True):
	'''
	Create time series features based on a datetime index
	'''
	
	df = df.copy()
	
	df['hour'] = df.index.hour
	df['weekday'] = df.index.dayofweek
	df['weekday_name'] = df.index.strftime('%A')
	df['month'] = df.index.month
	df['month_name'] = df.index.strftime('%B')
	df['quarter'] = df.index.quarter
	df['year'] = df.index.year
	df['week_of_year'] = df.index.isocalendar().week
	df['day_of_year'] = df.index.dayofyear
	
	if daytime:
		# Add column with category for time of day: 
		# midnight, early_morning, late_morning, afternoon, evening, night 
		def time_of_day(hour):
			if hour >= 0 and hour < 6:
				return 'midnight'
			elif hour >= 6 and hour < 9:
				return 'early_morning'
			elif hour >= 9 and hour < 12:
				return 'late_morning'
			elif hour >= 12 and hour < 15:
				return 'afternoon'
			elif hour >= 15 and hour < 18:
				return 'evening'
			else:
				return 'night'

		df['time_of_day'] = (df['hour'].apply(time_of_day)).astype('category')
		
	df['weekday_name'] = df['weekday_name'].astype('category')
	df['month_name'] = df['month_name'].astype('category')
	df['week_of_year'] = df.week_of_year.astype(float)
	
	return df

# %%
df = featurize_datetime_index(df)

# %%
head_tail_horz(df.sample(10), 5, 'DF with Added Datetime Features (Random Samples)', intraday=True)
# Out:
# <span style = 'display: block; width: 480.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>DF with Added Datetime Features (Random Samples)						</text></font></b></style>
# <center><style type="text/css">
# #T_5b23c caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_5b23c" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b23c_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_5b23c_level0_col1" class="col_heading level0 col1" >hour</th>
#       <th id="T_5b23c_level0_col2" class="col_heading level0 col2" >weekday</th>
#       <th id="T_5b23c_level0_col3" class="col_heading level0 col3" >weekday_name</th>
#       <th id="T_5b23c_level0_col4" class="col_heading level0 col4" >month</th>
#       <th id="T_5b23c_level0_col5" class="col_heading level0 col5" >month_name</th>
#       <th id="T_5b23c_level0_col6" class="col_heading level0 col6" >quarter</th>
#       <th id="T_5b23c_level0_col7" class="col_heading level0 col7" >year</th>
#       <th id="T_5b23c_level0_col8" class="col_heading level0 col8" >week_of_year</th>
#       <th id="T_5b23c_level0_col9" class="col_heading level0 col9" >day_of_year</th>
#       <th id="T_5b23c_level0_col10" class="col_heading level0 col10" >time_of_day</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b23c_level0_row0" class="row_heading level0 row0" >2007-11-23 01:00:00</th>
#       <td id="T_5b23c_row0_col0" class="data row0 col0" >24,065.00</td>
#       <td id="T_5b23c_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_5b23c_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_5b23c_row0_col3" class="data row0 col3" >Friday</td>
#       <td id="T_5b23c_row0_col4" class="data row0 col4" >11</td>
#       <td id="T_5b23c_row0_col5" class="data row0 col5" >November</td>
#       <td id="T_5b23c_row0_col6" class="data row0 col6" >4</td>
#       <td id="T_5b23c_row0_col7" class="data row0 col7" >2,007</td>
#       <td id="T_5b23c_row0_col8" class="data row0 col8" >47.00</td>
#       <td id="T_5b23c_row0_col9" class="data row0 col9" >327</td>
#       <td id="T_5b23c_row0_col10" class="data row0 col10" >midnight</td>
#     </tr>
#     <tr>
#       <th id="T_5b23c_level0_row1" class="row_heading level0 row1" >2014-08-16 12:00:00</th>
#       <td id="T_5b23c_row1_col0" class="data row1 col0" >29,530.00</td>
#       <td id="T_5b23c_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_5b23c_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_5b23c_row1_col3" class="data row1 col3" >Saturday</td>
#       <td id="T_5b23c_row1_col4" class="data row1 col4" >8</td>
#       <td id="T_5b23c_row1_col5" class="data row1 col5" >August</td>
#       <td id="T_5b23c_row1_col6" class="data row1 col6" >3</td>
#       <td id="T_5b23c_row1_col7" class="data row1 col7" >2,014</td>
#       <td id="T_5b23c_row1_col8" class="data row1 col8" >33.00</td>
#       <td id="T_5b23c_row1_col9" class="data row1 col9" >228</td>
#       <td id="T_5b23c_row1_col10" class="data row1 col10" >afternoon</td>
#     </tr>
#     <tr>
#       <th id="T_5b23c_level0_row2" class="row_heading level0 row2" >2002-09-14 22:00:00</th>
#       <td id="T_5b23c_row2_col0" class="data row2 col0" >34,282.00</td>
#       <td id="T_5b23c_row2_col1" class="data row2 col1" >22</td>
#       <td id="T_5b23c_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_5b23c_row2_col3" class="data row2 col3" >Saturday</td>
#       <td id="T_5b23c_row2_col4" class="data row2 col4" >9</td>
#       <td id="T_5b23c_row2_col5" class="data row2 col5" >September</td>
#       <td id="T_5b23c_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_5b23c_row2_col7" class="data row2 col7" >2,002</td>
#       <td id="T_5b23c_row2_col8" class="data row2 col8" >37.00</td>
#       <td id="T_5b23c_row2_col9" class="data row2 col9" >257</td>
#       <td id="T_5b23c_row2_col10" class="data row2 col10" >night</td>
#     </tr>
#     <tr>
#       <th id="T_5b23c_level0_row3" class="row_heading level0 row3" >2018-04-27 08:00:00</th>
#       <td id="T_5b23c_row3_col0" class="data row3 col0" >27,731.00</td>
#       <td id="T_5b23c_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_5b23c_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_5b23c_row3_col3" class="data row3 col3" >Friday</td>
#       <td id="T_5b23c_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_5b23c_row3_col5" class="data row3 col5" >April</td>
#       <td id="T_5b23c_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_5b23c_row3_col7" class="data row3 col7" >2,018</td>
#       <td id="T_5b23c_row3_col8" class="data row3 col8" >17.00</td>
#       <td id="T_5b23c_row3_col9" class="data row3 col9" >117</td>
#       <td id="T_5b23c_row3_col10" class="data row3 col10" >early_morning</td>
#     </tr>
#     <tr>
#       <th id="T_5b23c_level0_row4" class="row_heading level0 row4" >2012-12-25 13:00:00</th>
#       <td id="T_5b23c_row4_col0" class="data row4 col0" >29,238.00</td>
#       <td id="T_5b23c_row4_col1" class="data row4 col1" >13</td>
#       <td id="T_5b23c_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_5b23c_row4_col3" class="data row4 col3" >Tuesday</td>
#       <td id="T_5b23c_row4_col4" class="data row4 col4" >12</td>
#       <td id="T_5b23c_row4_col5" class="data row4 col5" >December</td>
#       <td id="T_5b23c_row4_col6" class="data row4 col6" >4</td>
#       <td id="T_5b23c_row4_col7" class="data row4 col7" >2,012</td>
#       <td id="T_5b23c_row4_col8" class="data row4 col8" >52.00</td>
#       <td id="T_5b23c_row4_col9" class="data row4 col9" >360</td>
#       <td id="T_5b23c_row4_col10" class="data row4 col10" >afternoon</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_9067f caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_9067f" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9067f_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_9067f_level0_col1" class="col_heading level0 col1" >hour</th>
#       <th id="T_9067f_level0_col2" class="col_heading level0 col2" >weekday</th>
#       <th id="T_9067f_level0_col3" class="col_heading level0 col3" >weekday_name</th>
#       <th id="T_9067f_level0_col4" class="col_heading level0 col4" >month</th>
#       <th id="T_9067f_level0_col5" class="col_heading level0 col5" >month_name</th>
#       <th id="T_9067f_level0_col6" class="col_heading level0 col6" >quarter</th>
#       <th id="T_9067f_level0_col7" class="col_heading level0 col7" >year</th>
#       <th id="T_9067f_level0_col8" class="col_heading level0 col8" >week_of_year</th>
#       <th id="T_9067f_level0_col9" class="col_heading level0 col9" >day_of_year</th>
#       <th id="T_9067f_level0_col10" class="col_heading level0 col10" >time_of_day</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9067f_level0_row0" class="row_heading level0 row0" >2011-01-18 05:00:00</th>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145354 entries, 2002-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   PJME_MW       145354 non-null  float64
#  1   hour          145354 non-null  int64
#  2   weekday       145354 non-null  int64
#  3   weekday_name  145354 non-null  category
#  4   month         145354 non-null  int64
#  5   month_name    145354 non-null  category
#  6   quarter       145354 non-null  int64
#  7   year          145354 non-null  int64
#  8   week_of_year  145354 non-null  float64
#  9   day_of_year   145354 non-null  int64
#  10  time_of_day   145354 non-null  category
# dtypes: category(3), float64(2), int64(6)
# memory usage: 10.4 MB

# %% [markdown]
# <a name="correlation"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Investigating Correlation**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Visualize Correlation Between Features and Target**

# %%
def boxplot_correlation(df, feature_x, feature_y, order = None, palette = None):
	
	fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
	ax.set_facecolor('LightGray')
	
	sns.boxplot(data = df, 
				x = feature_x, 
				y = feature_y,
			    order = order,
			    palette = palette)
	
	x_name = str(df[feature_x].name)
	y_name = str(df[feature_y].name)
	
	ax.grid()
	plt.xlabel(x_name, color = 'white', fontsize = 15)
	plt.ylabel(y_name, color = 'white', fontsize = 15)
	plt.xticks(color='white'); plt.yticks(color='white');
	plt.title(f'Feature Correlation: {x_name.capitalize()} - {y_name.capitalize()}', 
			  fontsize = 20, pad = 20, color = 'white');

# %%
boxplot_correlation(df, 'hour', 'PJME_MW', 
					palette = colors)

# %%
daytimes = ['midnight', 'early_morning', 'late_morning', 'afternoon', 
			'evening', 'night']

boxplot_correlation(df, 'time_of_day', 'PJME_MW', 
					order = daytimes, palette = colors)

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
                  'August', 'September', 'October', 'November', 'December']

boxplot_correlation(df, 'month_name', 'PJME_MW', 
					order = months, palette = colors)

# %%
boxplot_correlation(df, 'quarter', 'PJME_MW',
				   palette = colors)

# %%
boxplot_correlation(df, 'week_of_year', 'PJME_MW',
				   palette = colors)

# %% [markdown]
# <a name="lag_features"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Lag Features**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Forecasting Horizon & Lag Features**
# * Lag Features: telling the model to look back into the past, and use the target value for that many days back as a new feature fed into the model
# * in this case, it is a value from the energy usage column
# * we are saving this column as a `dict` called `target_map`
# * using 364 as the increment, because it is perfectly divisible by 7 and will line up days of the week
# * the forecast horizon cannot extend farther than the shortest lag chosen
# * using `map()` to map the values

# %%
def year_lags(df, target_column, lag_label_list):
	
	target_map = df[target_column].to_dict()
	inputs = lag_label_list.copy()
	
	for tup in inputs:
		df[tup[1]] = (df.index - pd.Timedelta(tup[0])).map(target_map)
	
	return df

# %%
lag_label_list = [('364 days', 'one_year'),
				  ('728 days', 'two_year'),
				  ('1092 days', 'three_year')]

# %%
df_lags = df.copy()
df_lags = year_lags(df_lags, 'PJME_MW', lag_label_list)

# %%
missing_values(df_lags[['one_year', 'two_year', 'three_year']])
# Out:
# <span style = 'display: block; width: 38%; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=3><text style=color:white>Columns and Missing Values						</text></font></b></style>
# <center><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column name</th>
#       <th>missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one_year</td>
#       <td>8755</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two_year</td>
#       <td>17497</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>three_year</td>
#       <td>26237</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a name="splitting"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Splitting the Data**</font></span>
# * Because I noticed that I actually got better results training without the lag features added, I will be running each operation on both the data without lag features and with lag features for comparison.

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Traditional Train-Test Split**
# * training data will be up through 2014
# * test data will be everything following the 2014 training data ending

# %%
train_data = df.iloc[df.index < '01-01-2015']
test_data = df.iloc[df.index >= '01-01-2015']
train_data = pd.get_dummies(data=train_data, columns = ['time_of_day'])
test_data = pd.get_dummies(data=test_data, columns = ['time_of_day'])

# %%
train_data_lags = df_lags.iloc[df.index < '01-01-2015']
test_data_lags = df_lags.iloc[df.index >= '01-01-2015']
train_data_lags = pd.get_dummies(data=train_data_lags, columns = ['time_of_day'])
test_data_lags = pd.get_dummies(data=test_data_lags, columns = ['time_of_day'])

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Visualizing the Traditional Train-Test Split**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
train_data.plot(ax = ax, label = 'Training Data', color = 'cyan');
test_data.plot(ax = ax, label = 'Testing Data', color = 'deeppink');
ax.grid()
ax.axvline('01-01-2015', color = 'yellow', ls = '--', linewidth = 3)
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white'); plt.yticks(color='white');
plt.title('Train-Test Split', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Defining Features & Targets**

# %%
features = ['hour', 'weekday', 'month', 'quarter', 'year', 
			'week_of_year', 'day_of_year', 'time_of_day_afternoon', 
			'time_of_day_early_morning', 'time_of_day_evening', 
			'time_of_day_late_morning', 'time_of_day_midnight', 
			'time_of_day_night']

features_lags = ['hour', 'weekday', 'month', 'quarter', 'year', 
			'week_of_year', 'day_of_year', 'time_of_day_afternoon', 
			'time_of_day_early_morning', 'time_of_day_evening', 
			'time_of_day_late_morning', 'time_of_day_midnight', 
			'time_of_day_night', 'one_year', 'two_year', 'three_year']
							 
target = "PJME_MW"

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Defining Training & Testing Data with Features**

# %%
train_in = train_data[features]
train_out = train_data[target]
test_in = test_data[features]
test_out = test_data[target]

# %%
train_in_lags = train_data_lags[features_lags]
train_out_lags = train_data_lags[target]
test_in_lags = test_data_lags[features_lags]
test_out_lags = test_data_lags[target]

# %% [markdown]
# <a name="model"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**The XGBoost Regressor Model**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Creating the Model (without lags)**

# %%
xgb_regressor = XGBRegressor(n_estimators = 1200,
							 learning_rate = 0.01, 
							 early_stopping_rounds = 50)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Fitting the Model (without lags)**

# %%
xgb_regressor.fit(train_in, train_out,
				 eval_set = [(train_in, train_out), 
							  (test_in, test_out)], 
				  verbose = 25)
# Out:
# [0]	validation_0-rmse:32603.16870	validation_1-rmse:31654.27391
# [25]	validation_0-rmse:25458.36519	validation_1-rmse:24505.19653
# [50]	validation_0-rmse:19922.28100	validation_1-rmse:18994.77264
# [75]	validation_0-rmse:15640.56226	validation_1-rmse:14765.00592
# [100]	validation_0-rmse:12342.33959	validation_1-rmse:11514.87314
# [125]	validation_0-rmse:9813.24872	validation_1-rmse:9102.76782
# [150]	validation_0-rmse:7888.31353	validation_1-rmse:7323.56932
# [175]	validation_0-rmse:6442.23464	validation_1-rmse:6041.08330
# [200]	validation_0-rmse:5370.60588	validation_1-rmse:5152.67945
# [225]	validation_0-rmse:4586.38582	validation_1-rmse:4554.97220
# [250]	validation_0-rmse:4029.08770	validation_1-rmse:4174.67280
# [275]	validation_0-rmse:3639.91800	validation_1-rmse:3951.31837
# [300]	validation_0-rmse:3369.86767	validation_1-rmse:3822.27300
# [325]	validation_0-rmse:3183.20994	validation_1-rmse:3755.76705
# [350]	validation_0-rmse:3051.93082	validation_1-rmse:3718.73452
# [375]	validation_0-rmse:2951.30687	validation_1-rmse:3702.53323
# [400]	validation_0-rmse:2873.96549	validation_1-rmse:3699.84669
# [425]	validation_0-rmse:2815.20201	validation_1-rmse:3703.75338
# [444]	validation_0-rmse:2775.11002	validation_1-rmse:3713.53981
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Fitting the Model (with lags)**

# %%
xgb_regressor_lags = XGBRegressor(n_estimators = 1200,
							 learning_rate = 0.01, 
							 early_stopping_rounds = 50)

# %%
xgb_regressor_lags.fit(train_in_lags, train_out_lags,
				 eval_set = [(train_in_lags, train_out_lags), 
							  (test_in_lags, test_out_lags)], 
				  verbose = 25)
# Out:
# [0]	validation_0-rmse:32603.39071	validation_1-rmse:31661.27585
# [25]	validation_0-rmse:25464.17590	validation_1-rmse:24716.80555
# [50]	validation_0-rmse:19933.04811	validation_1-rmse:19358.88731
# [75]	validation_0-rmse:15656.16771	validation_1-rmse:15244.89333
# [100]	validation_0-rmse:12361.61078	validation_1-rmse:12100.95921
# [125]	validation_0-rmse:9836.89936	validation_1-rmse:9722.02746
# [150]	validation_0-rmse:7915.57282	validation_1-rmse:7932.50134
# [175]	validation_0-rmse:6467.15649	validation_1-rmse:6614.64128
# [200]	validation_0-rmse:5393.12544	validation_1-rmse:5674.76573
# [225]	validation_0-rmse:4612.63544	validation_1-rmse:5011.37043
# [250]	validation_0-rmse:4055.10540	validation_1-rmse:4561.07582
# [275]	validation_0-rmse:3665.33420	validation_1-rmse:4279.36492
# [300]	validation_0-rmse:3398.10689	validation_1-rmse:4099.88945
# [325]	validation_0-rmse:3216.22259	validation_1-rmse:3995.55877
# [350]	validation_0-rmse:3092.09584	validation_1-rmse:3933.26218
# [375]	validation_0-rmse:3007.39146	validation_1-rmse:3899.01375
# [400]	validation_0-rmse:2945.12876	validation_1-rmse:3883.81110
# [425]	validation_0-rmse:2891.91191	validation_1-rmse:3881.37836
# [450]	validation_0-rmse:2843.84687	validation_1-rmse:3889.46506
# [465]	validation_0-rmse:2818.84115	validation_1-rmse:3892.62573
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Feature Importance (without lags)**

# %%
feature_importance = pd.DataFrame(data = xgb_regressor.feature_importances_,
									index = xgb_regressor.feature_names_in_,
									columns = ['importance'])

feature_importance = feature_importance[feature_importance.importance > 0.0005]

multi([(feature_importance.sort_values('importance', ascending = False), 
		'Feature Importance (no lags)')], precision = 4)
# Out:
# <center><style type="text/css">
# #T_f6bc9 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
# }
# </style>
# <table id="T_f6bc9" style='display:inline-block'>
#   <caption>Feature Importance (no lags)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6bc9_level0_col0" class="col_heading level0 col0" >importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6bc9_level0_row0" class="row_heading level0 row0" >hour</th>
#       <td id="T_f6bc9_row0_col0" class="data row0 col0" >0.4200</td>
#     </tr>
#     <tr>
#       <th id="T_f6bc9_level0_row1" class="row_heading level0 row1" >month</th>
#       <td id="T_f6bc9_row1_col0" class="data row1 col0" >0.1891</td>
#     </tr>
#     <tr>
#       <th id="T_f6bc9_level0_row2" class="row_heading level0 row2" >weekday</th>
#       <td id="T_f6bc9_row2_col0" class="data row2 col0" >0.1419</td>
#     </tr>
#     <tr>
#       <th id="T_f6bc9_level0_row3" class="row_heading level0 row3" >day_of_year</th>
#       <td id="T_f6bc9_row3_col0" class="data row3 col0" >0.1073</td>
#     </tr>
#     <tr>
#       <th id="T_f6bc9_level0_row4" class="row_heading level0 row4" >time_of_day_evening</th>
#       <td id="T_f6bc9_row4_col0" class="data row4 col0" >0.0572</td>
#     </tr>
#     <tr>
#       <th id="T_f6bc9_level0_row5" class="row_heading level0 row5" >week_of_year</th>
#       <td id="T_f6bc9_row5_col0" class="data row5 col0" >0.0518</td>
#     </tr>
#     <tr>
#       <th id="T_f6bc9_level0_row6" class="row_heading level0 row6" >year</th>
#       <td id="T_f6bc9_row6_col0" class="data row6 col0" >0.0199</td>
#     </tr>
#     <tr>
#       <th id="T_f6bc9_level0_row7" class="row_heading level0 row7" >time_of_day_afternoon</th>
#       <td id="T_f6bc9_row7_col0" class="data row7 col0" >0.0115</td>
#     </tr>
#     <tr>
#       <th id="T_f6bc9_level0_row8" class="row_heading level0 row8" >time_of_day_late_morning</th>
#       <td id="T_f6bc9_row8_col0" class="data row8 col0" >0.0011</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Plotting Feature Importance (without lags)**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')

feature_importance.sort_values('importance').plot(kind = 'barh', 
												  color = 'cyan', 
												  ax = ax)
ax.grid()
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white', size = 13); plt.yticks(color='white', size = 13);
plt.title('Feature Importance Without Lags', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Feature Importance (with lags)**

# %%
feature_importance_lags = pd.DataFrame(data = xgb_regressor.feature_importances_,
									index = xgb_regressor.feature_names_in_,
									columns = ['importance'])

feature_importance_lags = feature_importance_lags[feature_importance_lags.importance > 0.0005]

multi([(feature_importance_lags.sort_values('importance', ascending = False), 
		'Feature Importance (with lags)')], precision = 4)
# Out:
# <center><style type="text/css">
# #T_7b136 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
# }
# </style>
# <table id="T_7b136" style='display:inline-block'>
#   <caption>Feature Importance (with lags)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b136_level0_col0" class="col_heading level0 col0" >importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b136_level0_row0" class="row_heading level0 row0" >hour</th>
#       <td id="T_7b136_row0_col0" class="data row0 col0" >0.4200</td>
#     </tr>
#     <tr>
#       <th id="T_7b136_level0_row1" class="row_heading level0 row1" >month</th>
#       <td id="T_7b136_row1_col0" class="data row1 col0" >0.1891</td>
#     </tr>
#     <tr>
#       <th id="T_7b136_level0_row2" class="row_heading level0 row2" >weekday</th>
#       <td id="T_7b136_row2_col0" class="data row2 col0" >0.1419</td>
#     </tr>
#     <tr>
#       <th id="T_7b136_level0_row3" class="row_heading level0 row3" >day_of_year</th>
#       <td id="T_7b136_row3_col0" class="data row3 col0" >0.1073</td>
#     </tr>
#     <tr>
#       <th id="T_7b136_level0_row4" class="row_heading level0 row4" >time_of_day_evening</th>
#       <td id="T_7b136_row4_col0" class="data row4 col0" >0.0572</td>
#     </tr>
#     <tr>
#       <th id="T_7b136_level0_row5" class="row_heading level0 row5" >week_of_year</th>
#       <td id="T_7b136_row5_col0" class="data row5 col0" >0.0518</td>
#     </tr>
#     <tr>
#       <th id="T_7b136_level0_row6" class="row_heading level0 row6" >year</th>
#       <td id="T_7b136_row6_col0" class="data row6 col0" >0.0199</td>
#     </tr>
#     <tr>
#       <th id="T_7b136_level0_row7" class="row_heading level0 row7" >time_of_day_afternoon</th>
#       <td id="T_7b136_row7_col0" class="data row7 col0" >0.0115</td>
#     </tr>
#     <tr>
#       <th id="T_7b136_level0_row8" class="row_heading level0 row8" >time_of_day_late_morning</th>
#       <td id="T_7b136_row8_col0" class="data row8 col0" >0.0011</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Plotting Feature Importance (with lags)**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')

feature_importance_lags.sort_values('importance').plot(kind = 'barh', 
												  color = 'cyan', 
												  ax = ax)
ax.grid()
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white', size = 13); plt.yticks(color='white', size = 13);
plt.title('Feature Importance with Lags', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <a name="traditional_results"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Results with Traditional Train-Test Split**</font></span>
# * Because there is no benefit to having the lag data added, for the remainder of the project, I will be working with only the data without lags added.

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Predicting with Test Data**

# %%
test_data['prediction'] = xgb_regressor.predict(test_in)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Merging Predictions into Original DF**

# %%
df = df.merge(test_data['prediction'], 
			  how = 'left', 
			  left_index = True,
			  right_index = True)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Plotting Predictions vs Original Data**

# %%
plt.figure(facecolor = '#333333');
ax = df['PJME_MW'].plot(figsize = (13, 7), color = 'cyan');
ax.set_facecolor('#444444');
df['prediction'].plot(ax = ax, style = '.', color = 'deeppink');
plt.legend();
ax.grid()
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white', size = 13); plt.yticks(color='white', size = 13);
plt.title('Train-Test Split', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()
ax.set_title('Actual Data vs Predicted', color = 'white', size = 22, pad = 20);

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Predictions vs Targets: One Week Excerpt**

# %%
plt.figure(figsize = (13, 7), facecolor = '#333333')
ax = df.loc[(df.index > '04-01-2018') \
			& (df.index <= '04-08-2018')]\
			['PJME_MW'].plot(color = 'cyan', linewidth = 3);
df.loc[(df.index > '04-01-2018') \
			& (df.index <= '04-08-2018')]\
			['prediction'].plot(style = '.', color = 'yellow', markersize = 12);
ax.set_facecolor('#444444')
plt.legend();
ax.grid()
plt.xlabel('days', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Training Data vs Predictions: 1 Week Excerpt', fontsize = 20, pad = 20, color = 'white');
plt.legend(fontsize = 15, labelcolor = 'white', facecolor = '#333333');

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Prediction Accuracy**

# %%
pred_actual = df.loc[df.prediction.notna()]# [['PJME_MW', 'prediction']]

# %%
def get_accuracy(df, pred_col, actual_col):
	from sklearn.metrics import mean_squared_error
	df = df.copy()
	
	df['abs_acc'] = (1 - (abs(df[actual_col] - 
								   df[pred_col]) / df[actual_col])) * 100
	
	range_diff = np.max(df[actual_col]) - np.min(df[actual_col])
	
	df['rel_acc'] = (1 - (abs(df[actual_col] - 
								   df[pred_col]) / range_diff)) * 100 
	
	range_std = np.std(df[actual_col])
	
	df['sharpe'] = (abs(df[actual_col] - 
								   df[pred_col]) / range_std)
	
	rmse = np.sqrt(mean_squared_error(df[actual_col], 
										df[pred_col]))
	
	results = pd.Series([f"{rmse:,.2f}", 
						 f"{df['abs_acc'].mean():.2f}%",
						 f"{df['rel_acc'].mean():.2f}%",
						 f"{df['sharpe'].mean():.2f}"], 
						index = ['Average RMSE', 
								 'Average Absolute Accuracy', 
								 'Average Relative Accuracy',
								 'Average Sharpe Ratio'],
						name = "Resulting Metrics")
	
	see(results, 'Overall Metrics for Accuracy and Model Performance')

	return df

# %%
pred_actual = get_accuracy(pred_actual, 'PJME_MW', 'prediction')

head_tail_horz(pred_actual[['PJME_MW', 'prediction', 'abs_acc', 
							'rel_acc', 'sharpe']], 5, 'Predictions vs Actual Targets')
# Out:
# <span style = 'display: block; width: 500.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>Overall Metrics for Accuracy and Model Performance						</text></font></b></style>
# <center><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Resulting Metrics</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Average RMSE</th>
#       <td>3,698.86</td>
#     </tr>
#     <tr>
#       <th>Average Absolute Accuracy</th>
#       <td>91.35%</td>
#     </tr>
#     <tr>
#       <th>Average Relative Accuracy</th>
#       <td>88.57%</td>
#     </tr>
#     <tr>
#       <th>Average Sharpe Ratio</th>
#       <td>0.54</td>
#     </tr>
#   </tbody>
# </table>
# <span style = 'display: block; width: 290.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>Predictions vs Actual Targets						</text></font></b></style>
# <center><style type="text/css">
# #T_3550b caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_3550b" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3550b_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_3550b_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_3550b_level0_col2" class="col_heading level0 col2" >abs_acc</th>
#       <th id="T_3550b_level0_col3" class="col_heading level0 col3" >rel_acc</th>
#       <th id="T_3550b_level0_col4" class="col_heading level0 col4" >sharpe</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3550b_level0_row0" class="row_heading level0 row0" >2015-01-01</th>
#       <td id="T_3550b_row0_col0" class="data row0 col0" >32,802.00</td>
#       <td id="T_3550b_row0_col1" class="data row0 col1" >32,214.12</td>
#       <td id="T_3550b_row0_col2" class="data row0 col2" >98.18</td>
#       <td id="T_3550b_row0_col3" class="data row0 col3" >97.56</td>
#       <td id="T_3550b_row0_col4" class="data row0 col4" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_3550b_level0_row1" class="row_heading level0 row1" >2015-01-01</th>
#       <td id="T_3550b_row1_col0" class="data row1 col0" >31,647.00</td>
#       <td id="T_3550b_row1_col1" class="data row1 col1" >31,177.77</td>
#       <td id="T_3550b_row1_col2" class="data row1 col2" >98.49</td>
#       <td id="T_3550b_row1_col3" class="data row1 col3" >98.05</td>
#       <td id="T_3550b_row1_col4" class="data row1 col4" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_3550b_level0_row2" class="row_heading level0 row2" >2015-01-01</th>
#       <td id="T_3550b_row2_col0" class="data row2 col0" >30,755.00</td>
#       <td id="T_3550b_row2_col1" class="data row2 col1" >30,805.81</td>
#       <td id="T_3550b_row2_col2" class="data row2 col2" >99.84</td>
#       <td id="T_3550b_row2_col3" class="data row2 col3" >99.79</td>
#       <td id="T_3550b_row2_col4" class="data row2 col4" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_3550b_level0_row3" class="row_heading level0 row3" >2015-01-01</th>
#       <td id="T_3550b_row3_col0" class="data row3 col0" >30,189.00</td>
#       <td id="T_3550b_row3_col1" class="data row3 col1" >30,992.76</td>
#       <td id="T_3550b_row3_col2" class="data row3 col2" >97.41</td>
#       <td id="T_3550b_row3_col3" class="data row3 col3" >96.66</td>
#       <td id="T_3550b_row3_col4" class="data row3 col4" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_3550b_level0_row4" class="row_heading level0 row4" >2015-01-01</th>
#       <td id="T_3550b_row4_col0" class="data row4 col0" >29,890.00</td>
#       <td id="T_3550b_row4_col1" class="data row4 col1" >30,992.76</td>
#       <td id="T_3550b_row4_col2" class="data row4 col2" >96.44</td>
#       <td id="T_3550b_row4_col3" class="data row4 col3" >95.42</td>
#       <td id="T_3550b_row4_col4" class="data row4 col4" >0.22</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_6ef92 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_6ef92" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ef92_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_6ef92_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_6ef92_level0_col2" class="col_heading level0 col2" >abs_acc</th>
#       <th id="T_6ef92_level0_col3" class="col_heading level0 col3" >rel_acc</th>
#       <th id="T_6ef92_level0_col4" class="col_heading level0 col4" >sharpe</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ef92_level0_row0" class="row_heading level0 row0" >2018-08-02</th>
#       <td id="T_6ef92_row0_col0" class="data row0 col0" >44,057.00</td>
#       <td id="T_6ef92_row0_col1" class="data row0 col1" >41,066.02</td>
#       <td id="T_6ef92_row0_col2" class="data row0 col2" >92.72</td>
#       <td id="T_6ef92_row0_col3" class="data row0 col3" >87.57</td>
#       <td id="T_6ef92_row0_col4" class="data row0 col4" >0.59</td>
#     </tr>
#     <tr>
#       <th id="T_6ef92_level0_row1" class="row_heading level0 row1" >2018-08-02</th>
#       <td id="T_6ef92_row1_col0" class="data row1 col0" >43,256.00</td>
#       <td id="T_6ef92_row1_col1" class="data row1 col1" >40,472.05</td>
#       <td id="T_6ef92_row1_col2" class="data row1 col2" >93.12</td>
#       <td id="T_6ef92_row1_col3" class="data row1 col3" >88.43</td>
#       <td id="T_6ef92_row1_col4" class="data row1 col4" >0.55</td>
#     </tr>
#     <tr>
#       <th id="T_6ef92_level0_row2" class="row_heading level0 row2" >2018-08-02</th>
#       <td id="T_6ef92_row2_col0" class="data row2 col0" >41,552.00</td>
#       <td id="T_6ef92_row2_col1" class="data row2 col1" >39,112.41</td>
#       <td id="T_6ef92_row2_col2" class="data row2 col2" >93.76</td>
#       <td id="T_6ef92_row2_col3" class="data row2 col3" >89.86</td>
#       <td id="T_6ef92_row2_col4" class="data row2 col4" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_6ef92_level0_row3" class="row_heading level0 row3" >2018-08-02</th>
#       <td id="T_6ef92_row3_col0" class="data row3 col0" >38,500.00</td>
#       <td id="T_6ef92_row3_col1" class="data row3 col1" >36,054.58</td>
#       <td id="T_6ef92_row3_col2" class="data row3 col2" >93.22</td>
#       <td id="T_6ef92_row3_col3" class="data row3 col3" >89.84</td>
#       <td id="T_6ef92_row3_col4" class="data row3 col4" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_6ef92_level0_row4" class="row_heading level0 row4" >2018-08-03</th>
#       <td id="T_6ef92_row4_col0" class="data row4 col0" >35,486.00</td>
#       <td id="T_6ef92_row4_col1" class="data row4 col1" >31,266.94</td>
#       <td id="T_6ef92_row4_col2" class="data row4 col2" >86.51</td>
#       <td id="T_6ef92_row4_col3" class="data row4 col3" >82.47</td>
#       <td id="T_6ef92_row4_col4" class="data row4 col4" >0.83</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Plotting the Sharpe Ratio**

# %%
plt.figure(figsize = (13, 7), facecolor = '#333333')
ax = plt.axes()
pred_actual.sharpe.plot(kind="hist", 
						bins=100, 
						color = 'cyan',
						edgecolor = 'white',  
						ax = ax)
ax.set_facecolor('#444444')
plt.legend();
ax.grid()
plt.xlabel('sharpe ratio', color = 'white', fontsize = 15)
plt.ylabel('count', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Overall Distribution of Sharpe Ratio Metrics', 
		  fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Daily Error - Investigating the Days with the Highest and Lowest Error**

# %%
def get_daily_error(df, actual_col, pred_col, num_examples, 
					ascending = False):
	
	temp = df[[actual_col, pred_col]].copy()
	temp['date'] = temp.index.strftime('%A %b %d, %Y')
	temp['error'] = np.abs(df[actual_col] - df[pred_col])
	
	results = temp.sort_values("error", ascending = ascending)
	
	return results[['date', 
					'error', 
					pred_col, 
					actual_col]].head(num_examples).style.hide(axis='index')

# %%
get_daily_error(pred_actual, 'PJME_MW', 'prediction', 10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6116">
#   <thead>
#     <tr>
#       <th id="T_d6116_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_d6116_level0_col1" class="col_heading level0 col1" >error</th>
#       <th id="T_d6116_level0_col2" class="col_heading level0 col2" >prediction</th>
#       <th id="T_d6116_level0_col3" class="col_heading level0 col3" >PJME_MW</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d6116_row0_col0" class="data row0 col0" >Saturday Aug 13, 2016</td>
#       <td id="T_d6116_row0_col1" class="data row0 col1" >20318.644531</td>
#       <td id="T_d6116_row0_col2" class="data row0 col2" >34580.355469</td>
#       <td id="T_d6116_row0_col3" class="data row0 col3" >54899.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row1_col0" class="data row1 col0" >Saturday Aug 13, 2016</td>
#       <td id="T_d6116_row1_col1" class="data row1 col1" >19893.003906</td>
#       <td id="T_d6116_row1_col2" class="data row1 col2" >35056.996094</td>
#       <td id="T_d6116_row1_col3" class="data row1 col3" >54950.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row2_col0" class="data row2 col0" >Saturday Aug 13, 2016</td>
#       <td id="T_d6116_row2_col1" class="data row2 col1" >19875.636719</td>
#       <td id="T_d6116_row2_col2" class="data row2 col2" >35240.363281</td>
#       <td id="T_d6116_row2_col3" class="data row2 col3" >55116.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row3_col0" class="data row3 col0" >Saturday Aug 13, 2016</td>
#       <td id="T_d6116_row3_col1" class="data row3 col1" >19704.644531</td>
#       <td id="T_d6116_row3_col2" class="data row3 col2" >34580.355469</td>
#       <td id="T_d6116_row3_col3" class="data row3 col3" >54285.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row4_col0" class="data row4 col0" >Saturday Aug 13, 2016</td>
#       <td id="T_d6116_row4_col1" class="data row4 col1" >19249.972656</td>
#       <td id="T_d6116_row4_col2" class="data row4 col2" >34303.027344</td>
#       <td id="T_d6116_row4_col3" class="data row4 col3" >53553.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row5_col0" class="data row5 col0" >Saturday Aug 13, 2016</td>
#       <td id="T_d6116_row5_col1" class="data row5 col1" >19053.617188</td>
#       <td id="T_d6116_row5_col2" class="data row5 col2" >35015.382812</td>
#       <td id="T_d6116_row5_col3" class="data row5 col3" >54069.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row6_col0" class="data row6 col0" >Sunday Aug 14, 2016</td>
#       <td id="T_d6116_row6_col1" class="data row6 col1" >18932.144531</td>
#       <td id="T_d6116_row6_col2" class="data row6 col2" >34113.855469</td>
#       <td id="T_d6116_row6_col3" class="data row6 col3" >53046.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row7_col0" class="data row7 col0" >Sunday Aug 14, 2016</td>
#       <td id="T_d6116_row7_col1" class="data row7 col1" >18864.234375</td>
#       <td id="T_d6116_row7_col2" class="data row7 col2" >35068.765625</td>
#       <td id="T_d6116_row7_col3" class="data row7 col3" >53933.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row8_col0" class="data row8 col0" >Sunday Aug 14, 2016</td>
#       <td id="T_d6116_row8_col1" class="data row8 col1" >18542.832031</td>
#       <td id="T_d6116_row8_col2" class="data row8 col2" >35173.167969</td>
#       <td id="T_d6116_row8_col3" class="data row8 col3" >53716.000000</td>
#     </tr>
#     <tr>
#       <td id="T_d6116_row9_col0" class="data row9 col0" >Saturday Sep 10, 2016</td>
#       <td id="T_d6116_row9_col1" class="data row9 col1" >18517.148438</td>
#       <td id="T_d6116_row9_col2" class="data row9 col2" >31735.851562</td>
#       <td id="T_d6116_row9_col3" class="data row9 col3" >50253.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_daily_error(pred_actual, 'PJME_MW', 'prediction', 10,
			   ascending = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8cbe">
#   <thead>
#     <tr>
#       <th id="T_b8cbe_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_b8cbe_level0_col1" class="col_heading level0 col1" >error</th>
#       <th id="T_b8cbe_level0_col2" class="col_heading level0 col2" >prediction</th>
#       <th id="T_b8cbe_level0_col3" class="col_heading level0 col3" >PJME_MW</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b8cbe_row0_col0" class="data row0 col0" >Monday Aug 22, 2016</td>
#       <td id="T_b8cbe_row0_col1" class="data row0 col1" >0.035156</td>
#       <td id="T_b8cbe_row0_col2" class="data row0 col2" >33829.035156</td>
#       <td id="T_b8cbe_row0_col3" class="data row0 col3" >33829.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row1_col0" class="data row1 col0" >Tuesday Mar 22, 2016</td>
#       <td id="T_b8cbe_row1_col1" class="data row1 col1" >0.117188</td>
#       <td id="T_b8cbe_row1_col2" class="data row1 col2" >26020.117188</td>
#       <td id="T_b8cbe_row1_col3" class="data row1 col3" >26020.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row2_col0" class="data row2 col0" >Saturday Jan 23, 2016</td>
#       <td id="T_b8cbe_row2_col1" class="data row2 col1" >0.312500</td>
#       <td id="T_b8cbe_row2_col2" class="data row2 col2" >34321.312500</td>
#       <td id="T_b8cbe_row2_col3" class="data row2 col3" >34321.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row3_col0" class="data row3 col0" >Monday Mar 07, 2016</td>
#       <td id="T_b8cbe_row3_col1" class="data row3 col1" >0.431641</td>
#       <td id="T_b8cbe_row3_col2" class="data row3 col2" >27225.431641</td>
#       <td id="T_b8cbe_row3_col3" class="data row3 col3" >27225.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row4_col0" class="data row4 col0" >Friday May 11, 2018</td>
#       <td id="T_b8cbe_row4_col1" class="data row4 col1" >0.564453</td>
#       <td id="T_b8cbe_row4_col2" class="data row4 col2" >29522.435547</td>
#       <td id="T_b8cbe_row4_col3" class="data row4 col3" >29523.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row5_col0" class="data row5 col0" >Wednesday Nov 09, 2016</td>
#       <td id="T_b8cbe_row5_col1" class="data row5 col1" >0.863281</td>
#       <td id="T_b8cbe_row5_col2" class="data row5 col2" >32424.863281</td>
#       <td id="T_b8cbe_row5_col3" class="data row5 col3" >32424.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row6_col0" class="data row6 col0" >Wednesday Apr 13, 2016</td>
#       <td id="T_b8cbe_row6_col1" class="data row6 col1" >0.880859</td>
#       <td id="T_b8cbe_row6_col2" class="data row6 col2" >23304.119141</td>
#       <td id="T_b8cbe_row6_col3" class="data row6 col3" >23305.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row7_col0" class="data row7 col0" >Sunday Jun 11, 2017</td>
#       <td id="T_b8cbe_row7_col1" class="data row7 col1" >0.937500</td>
#       <td id="T_b8cbe_row7_col2" class="data row7 col2" >23106.062500</td>
#       <td id="T_b8cbe_row7_col3" class="data row7 col3" >23107.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row8_col0" class="data row8 col0" >Monday Mar 21, 2016</td>
#       <td id="T_b8cbe_row8_col1" class="data row8 col1" >0.947266</td>
#       <td id="T_b8cbe_row8_col2" class="data row8 col2" >27448.947266</td>
#       <td id="T_b8cbe_row8_col3" class="data row8 col3" >27448.000000</td>
#     </tr>
#     <tr>
#       <td id="T_b8cbe_row9_col0" class="data row9 col0" >Thursday Mar 22, 2018</td>
#       <td id="T_b8cbe_row9_col1" class="data row9 col1" >0.984375</td>
#       <td id="T_b8cbe_row9_col2" class="data row9 col2" >33437.015625</td>
#       <td id="T_b8cbe_row9_col3" class="data row9 col3" >33438.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a name="cross_validation"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Training the Model Using Cross Validation**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**What is Cross Validation?**
# * using sklearn `TimeSeriesSplit()`
# * test size is 1 year of hourly records
# * a gap of 24 puts a 1 day gap between the end of a training set and beginning of a test set
# * must be sure time series data is sorted so that the time series split will work

# %%
time_series_split = TimeSeriesSplit(n_splits = 5,
								    test_size = (24 * 365 * 1),
								    gap = 24)

df = df.sort_index()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**This creates a time series split generator object**
# * this object will be applied across the data
# * it will loop over the data 5 times

# %%
time_series_split
# Out:
# TimeSeriesSplit(gap=24, max_train_size=None, n_splits=5, test_size=8760)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Visualizing the `TimeSeriesSplit()` process**
#
# * for each fold, the model goes back and tests the testing data in 1 year increments, independently from the rest of the testing data
# * this is a very good approach when the dataset has a large number of records

# %%
for train_index, validation_index in time_series_split.split(df):
	break
pretty(train_index, 'Indices of training data:')
pretty(validation_index, 'Indices of validation data:'); sp()
# Out:
# <span style = 'line-height: 2;                                 background: #ececec; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:#111111>Indices of training data:                                </text></font></b></style>
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>[     0      1      2 ... 101533 101534 101535]                                </text></font></b></style>
# <span style = 'line-height: 2;                                 background: #ececec; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:#111111>Indices of validation data:                                </text></font></b></style>
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>[101560 101561 101562 ... 110317 110318 110319]                                </text></font></b></style>

# %%
fig, axs = plt.subplots(5, 1, figsize = (13, 10),
					   sharex = True, facecolor = "#222222")

fold = 0
for train_index, validation_index in time_series_split.split(df):
	training = df.iloc[train_index]
	validation = df.iloc[validation_index]
	
	ax = axs[fold]
	ax.set_facecolor('#444444')
	ax.set_title(f'Training & Testing splot for fold no. {fold}', 
				 fontsize = 15, color = 'white')
	ax.tick_params(color = 'white', labelcolor = 'white')

	training['PJME_MW'].plot(ax = ax,
							label = 'Training Set',
							color = 'cyan')
	validation['PJME_MW'].plot(ax = ax,
							label = 'Validation Set',
							  color = 'deeppink')

	axs[fold].axvline(validation.index.min(), 
					  color = 'white', ls = "--", linewidth = 3)
	
	axs[0].legend(fontsize=16, facecolor = '#222222', labelcolor = 'white')

	fold += 1

plt.suptitle('5 Different Folds of Cross Validation', color = 'white', fontsize = 24)
plt.tight_layout()

# %%
df = data.query('PJME_MW > 18_500').copy()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Training with Cross Validation**
# * this will repeat the steps above in order to now train with cross validation and the `TimeSeriesSplit()` method

# %%
def cross_validation_train(df, target_col,
							lab_label_list, lags = False, 
							splits = 5, test_size = (24 * 365 * 1),
							gap = 24, base_score = 0.5, booster = 'gbtree',
							n_estimators = 1200, early_stopping_rounds = 50,
							objective = 'reg:linear', max_depth = 3,
							learning_rate = 0.01, verbose = 25):
	
	from sklearn.metrics import mean_squared_error
	from sklearn.model_selection import TimeSeriesSplit
	
	df = featurize_datetime_index(df)
	target = target_col
	
	if lags:
		df = year_lags(df, 'target_column', lag_label_list)
		features = list(df.columns)
		features.remove('weekday_name')
		features.remove('month_name')
		features.remove(target)
	else:
		features = list(df.columns)
		features.remove(target)
		
	fold = 0
	prediction_log = []
	rmse_log = []
		
	df = df.sort_index()
	time_series_split = TimeSeriesSplit(n_splits = splits,
								    test_size = test_size,
								    gap = gap)
	
	for train_index, validation_index in time_series_split.split(df):
		training = df.iloc[train_index]
		validation = df.iloc[validation_index]
		
		train_in = training[features]
		train_out = training[target]
		test_in = validation[features]
		test_out = validation[target]
		
		model = xgb.XGBRegressor(base_score = base_score,
							   booster = booster,
							   n_estimators = n_estimators,
							   early_stopping_rounds = early_stopping_rounds,
							   objective = objective,
							   max_depth = max_depth,
							   learning_rate = learning_rate)
		
		model.fit(train_in, train_out,
				 eval_set = [(train_in, train_out), 
							  (test_in, test_out)], 
				  verbose = verbose)
		
		prediction = model.predict(test_in)
		prediction_log.append(prediction)
		rmse = np.sqrt(mean_squared_error(test_out, prediction))
		rmse_log.append(rmse)
		
# Finish with video
# Figure out how to make a log for accuracy as above
# space out columns on the Daily Error above

# %%
cross_validation_train(df, 
					   target_col = ,
					   lab_label_list = )
# Out:
#   Cell In[60], line 2
#     target_col = ,
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# <a name="cross_results"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Results of Cross-Validation**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Text**

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Text**

# %% [markdown]
# <a name="conclusions"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Cross Validation Results](#cross_results)   ●  [Conclusions](#conclusions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Conclusions**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Text**
