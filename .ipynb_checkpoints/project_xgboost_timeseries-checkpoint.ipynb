# %% [markdown]
# <a name="top"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# # Time Series Forecasting with XGBoost

# %%
from helpers import *
import_all()
from xgboost import XGBRegressor
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# <a name="data"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**The Data**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Importing Data**

# %%
data = pd.read_csv("energy_data/pjm_hourly_est.csv", index_col = "Datetime")
data.index = pd.to_datetime(data.index)
head_tail_horz(data, 5, "PJME", intraday=True)
# Out:
# <span style = 'display: block; width: 40.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>PJME						</text></font></b></style>
# <center><style type="text/css">
# #T_5d89d caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_5d89d" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d89d_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d89d_level0_row0" class="row_heading level0 row0" >2002-12-31 01:00:00</th>
#       <td id="T_5d89d_row0_col0" class="data row0 col0" >26,498.00</td>
#     </tr>
#     <tr>
#       <th id="T_5d89d_level0_row1" class="row_heading level0 row1" >2002-12-31 02:00:00</th>
#       <td id="T_5d89d_row1_col0" class="data row1 col0" >25,147.00</td>
#     </tr>
#     <tr>
#       <th id="T_5d89d_level0_row2" class="row_heading level0 row2" >2002-12-31 03:00:00</th>
#       <td id="T_5d89d_row2_col0" class="data row2 col0" >24,574.00</td>
#     </tr>
#     <tr>
#       <th id="T_5d89d_level0_row3" class="row_heading level0 row3" >2002-12-31 04:00:00</th>
#       <td id="T_5d89d_row3_col0" class="data row3 col0" >24,393.00</td>
#     </tr>
#     <tr>
#       <th id="T_5d89d_level0_row4" class="row_heading level0 row4" >2002-12-31 05:00:00</th>
#       <td id="T_5d89d_row4_col0" class="data row4 col0" >24,860.00</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_bc0fc caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_bc0fc" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc0fc_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc0fc_level0_row0" class="row_heading level0 row0" >2018-01-01 20:00:00</th>
#       <td id="T_bc0fc_row0_col0" class="data row0 col0" >44,284.00</td>
#     </tr>
#     <tr>
#       <th id="T_bc0fc_level0_row1" class="row_heading level0 row1" >2018-01-01 21:00:00</th>
#       <td id="T_bc0fc_row1_col0" class="data row1 col0" >43,751.00</td>
#     </tr>
#     <tr>
#       <th id="T_bc0fc_level0_row2" class="row_heading level0 row2" >2018-01-01 22:00:00</th>
#       <td id="T_bc0fc_row2_col0" class="data row2 col0" >42,402.00</td>
#     </tr>
#     <tr>
#       <th id="T_bc0fc_level0_row3" class="row_heading level0 row3" >2018-01-01 23:00:00</th>
#       <td id="T_bc0fc_row3_col0" class="data row3 col0" >40,164.00</td>
#     </tr>
#     <tr>
#       <th id="T_bc0fc_level0_row4" class="row_heading level0 row4" >2018-01-02 00:00:00</th>
#       <td id="T_bc0fc_row4_col0" class="data row4 col0" >38,608.00</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145366 entries, 2002-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   PJME_MW  145366 non-null  float64
# dtypes: float64(1)
# memory usage: 2.2 MB

# %%
data.shape
# Out:
# (145366, 1)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Initial Plotting**

# %%
colors = sns.color_palette('husl', 11)
colors
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8836443049112893, 0.5240073524369634, 0.19569304285113343),
#  (0.710130687316902, 0.6046852192663268, 0.19426060163712158),
#  (0.5432776721247529, 0.6540981095185215, 0.19324494273892204),
#  (0.19592059105779686, 0.6981620017487838, 0.3452219818913641),
#  (0.2067117296964458, 0.6829103404254792, 0.5829988925822328),
#  (0.21420912437215422, 0.6714963557258681, 0.6986206664203177),
#  (0.22537170008202412, 0.6531400148480775, 0.841007805313343),
#  (0.5596943802099308, 0.5764402169887779, 0.9583930713150347),
#  (0.8578978803740231, 0.44058452715322166, 0.957819659566579),
#  (0.9628653850704806, 0.4025928454059796, 0.7779310354076443)]

# %%
fig = plt.figure(facecolor = '#333333', figsize = (13,7));
ax = plt.axes();
ax.set_facecolor('#444444')
data.plot(style = '.', 
		  color = colors[9], 
		  ax = ax);
ax.grid()
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white'); plt.yticks(color='white');
plt.title('PJME Energy Use (Megawatts)', fontsize = 24, pad = 20, color = 'white');

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Looking at a Single Week of Data**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
data.iloc[(data.index > '01-01-2010') \
		  & (data.index < '01-08-2010')].plot(ax = ax, 
											  linewidth = 3,
											  color = colors[6])
ax.grid()
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Energy Usage: January 1 - 8, 2010', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <a name="outliers"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Removing Outlier Data**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Removing Outlier: the sudden dip in late 2012**

# %%
data.loc[data.PJME_MW == min(data.PJME_MW)]
# Out:
#                       PJME_MW
# Datetime
# 2012-10-30 04:00:00 14,544.00

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Investigating the month span centered on outlier data**

# %%
outlier_span = data.loc['2012-10-15' : '2012-11-15']

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
outlier_span.plot(ax = ax, 
				  linewidth = 3,
				  color = colors[6])
ax.grid()
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('One Month Centered on Outlier', fontsize = 24, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Investigating the day of the outlier**

# %%
outlier_day = data.loc['2012-10-29':'2012-10-30']

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
outlier_day.plot(ax = ax, 
				  linewidth = 3,
				  color = colors[6])
ax.grid()
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Day of Outlier', fontsize = 24, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Distribution of Energy Use Values**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
data['PJME_MW'].plot(kind = 'hist', bins = 250,
				  color = 'deeppink', edgecolor = 'white');
ax.grid()
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Distribution of Energy Use Values', fontsize = 24, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Investigating records where the value goes below histogram min**

# %%
minimals = data.query('PJME_MW < 18_500')

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
minimals.plot(style = '.', markersize = 25,
				  color = 'deeppink', ax = ax);
ax.grid()
ax.set_ylim(10000, 40000)
plt.xlabel('dates', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Oulier Low Point', fontsize = 24, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Overwriting the dataframe eliminating records less than 18,500 & Saving as the DF**

# %%
df = data.query('PJME_MW > 18_500').copy()

# %% [markdown]
# <a name="features"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Feature Engineering**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Time Series DateTime Index Feature Creation**

# %%
def featurize_datetime_index(df, daytime = True):
	'''
	Create time series features based on a datetime index
	'''
	
	df = df.copy()
	
	df['hour'] = df.index.hour
	df['weekday'] = df.index.dayofweek
	df['weekday_name'] = df.index.strftime('%A')
	df['month'] = df.index.month
	df['month_name'] = df.index.strftime('%B')
	df['quarter'] = df.index.quarter
	df['year'] = df.index.year
	df['week_of_year'] = df.index.isocalendar().week
	df['day_of_year'] = df.index.dayofyear
	
	if daytime:
		# Add column with category for time of day: 
		# midnight, early_morning, late_morning, afternoon, evening, night 
		def time_of_day(hour):
			if hour >= 0 and hour < 6:
				return 'midnight'
			elif hour >= 6 and hour < 9:
				return 'early_morning'
			elif hour >= 9 and hour < 12:
				return 'late_morning'
			elif hour >= 12 and hour < 15:
				return 'afternoon'
			elif hour >= 15 and hour < 18:
				return 'evening'
			else:
				return 'night'

		df['time_of_day'] = (df['hour'].apply(time_of_day)).astype('category')
		
	df['weekday_name'] = df['weekday_name'].astype('category')
	df['month_name'] = df['month_name'].astype('category')
	
	return df

# %%
df = featurize_datetime_index(df)

# %%
head_tail_horz(df.sample(10), 5, 'DF with Added Datetime Features (Random Samples)', intraday=True)
# Out:
# <span style = 'display: block; width: 480.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>DF with Added Datetime Features (Random Samples)						</text></font></b></style>
# <center><style type="text/css">
# #T_eef7d caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_eef7d" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eef7d_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_eef7d_level0_col1" class="col_heading level0 col1" >hour</th>
#       <th id="T_eef7d_level0_col2" class="col_heading level0 col2" >weekday</th>
#       <th id="T_eef7d_level0_col3" class="col_heading level0 col3" >weekday_name</th>
#       <th id="T_eef7d_level0_col4" class="col_heading level0 col4" >month</th>
#       <th id="T_eef7d_level0_col5" class="col_heading level0 col5" >month_name</th>
#       <th id="T_eef7d_level0_col6" class="col_heading level0 col6" >quarter</th>
#       <th id="T_eef7d_level0_col7" class="col_heading level0 col7" >year</th>
#       <th id="T_eef7d_level0_col8" class="col_heading level0 col8" >week_of_year</th>
#       <th id="T_eef7d_level0_col9" class="col_heading level0 col9" >day_of_year</th>
#       <th id="T_eef7d_level0_col10" class="col_heading level0 col10" >time_of_day</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eef7d_level0_row0" class="row_heading level0 row0" >2018-07-05 14:00:00</th>
#       <td id="T_eef7d_row0_col0" class="data row0 col0" >50,094.00</td>
#       <td id="T_eef7d_row0_col1" class="data row0 col1" >14</td>
#       <td id="T_eef7d_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_eef7d_row0_col3" class="data row0 col3" >Thursday</td>
#       <td id="T_eef7d_row0_col4" class="data row0 col4" >7</td>
#       <td id="T_eef7d_row0_col5" class="data row0 col5" >July</td>
#       <td id="T_eef7d_row0_col6" class="data row0 col6" >3</td>
#       <td id="T_eef7d_row0_col7" class="data row0 col7" >2,018</td>
#       <td id="T_eef7d_row0_col8" class="data row0 col8" >27</td>
#       <td id="T_eef7d_row0_col9" class="data row0 col9" >186</td>
#       <td id="T_eef7d_row0_col10" class="data row0 col10" >afternoon</td>
#     </tr>
#     <tr>
#       <th id="T_eef7d_level0_row1" class="row_heading level0 row1" >2007-02-20 01:00:00</th>
#       <td id="T_eef7d_row1_col0" class="data row1 col0" >32,439.00</td>
#       <td id="T_eef7d_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_eef7d_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_eef7d_row1_col3" class="data row1 col3" >Tuesday</td>
#       <td id="T_eef7d_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_eef7d_row1_col5" class="data row1 col5" >February</td>
#       <td id="T_eef7d_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_eef7d_row1_col7" class="data row1 col7" >2,007</td>
#       <td id="T_eef7d_row1_col8" class="data row1 col8" >8</td>
#       <td id="T_eef7d_row1_col9" class="data row1 col9" >51</td>
#       <td id="T_eef7d_row1_col10" class="data row1 col10" >midnight</td>
#     </tr>
#     <tr>
#       <th id="T_eef7d_level0_row2" class="row_heading level0 row2" >2006-08-22 18:00:00</th>
#       <td id="T_eef7d_row2_col0" class="data row2 col0" >47,756.00</td>
#       <td id="T_eef7d_row2_col1" class="data row2 col1" >18</td>
#       <td id="T_eef7d_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_eef7d_row2_col3" class="data row2 col3" >Tuesday</td>
#       <td id="T_eef7d_row2_col4" class="data row2 col4" >8</td>
#       <td id="T_eef7d_row2_col5" class="data row2 col5" >August</td>
#       <td id="T_eef7d_row2_col6" class="data row2 col6" >3</td>
#       <td id="T_eef7d_row2_col7" class="data row2 col7" >2,006</td>
#       <td id="T_eef7d_row2_col8" class="data row2 col8" >34</td>
#       <td id="T_eef7d_row2_col9" class="data row2 col9" >234</td>
#       <td id="T_eef7d_row2_col10" class="data row2 col10" >night</td>
#     </tr>
#     <tr>
#       <th id="T_eef7d_level0_row3" class="row_heading level0 row3" >2004-03-05 01:00:00</th>
#       <td id="T_eef7d_row3_col0" class="data row3 col0" >24,837.00</td>
#       <td id="T_eef7d_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_eef7d_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_eef7d_row3_col3" class="data row3 col3" >Friday</td>
#       <td id="T_eef7d_row3_col4" class="data row3 col4" >3</td>
#       <td id="T_eef7d_row3_col5" class="data row3 col5" >March</td>
#       <td id="T_eef7d_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_eef7d_row3_col7" class="data row3 col7" >2,004</td>
#       <td id="T_eef7d_row3_col8" class="data row3 col8" >10</td>
#       <td id="T_eef7d_row3_col9" class="data row3 col9" >65</td>
#       <td id="T_eef7d_row3_col10" class="data row3 col10" >midnight</td>
#     </tr>
#     <tr>
#       <th id="T_eef7d_level0_row4" class="row_heading level0 row4" >2011-10-13 04:00:00</th>
#       <td id="T_eef7d_row4_col0" class="data row4 col0" >22,200.00</td>
#       <td id="T_eef7d_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_eef7d_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_eef7d_row4_col3" class="data row4 col3" >Thursday</td>
#       <td id="T_eef7d_row4_col4" class="data row4 col4" >10</td>
#       <td id="T_eef7d_row4_col5" class="data row4 col5" >October</td>
#       <td id="T_eef7d_row4_col6" class="data row4 col6" >4</td>
#       <td id="T_eef7d_row4_col7" class="data row4 col7" >2,011</td>
#       <td id="T_eef7d_row4_col8" class="data row4 col8" >41</td>
#       <td id="T_eef7d_row4_col9" class="data row4 col9" >286</td>
#       <td id="T_eef7d_row4_col10" class="data row4 col10" >midnight</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_6264f caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_6264f" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6264f_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_6264f_level0_col1" class="col_heading level0 col1" >hour</th>
#       <th id="T_6264f_level0_col2" class="col_heading level0 col2" >weekday</th>
#       <th id="T_6264f_level0_col3" class="col_heading level0 col3" >weekday_name</th>
#       <th id="T_6264f_level0_col4" class="col_heading level0 col4" >month</th>
#       <th id="T_6264f_level0_col5" class="col_heading level0 col5" >month_name</th>
#       <th id="T_6264f_level0_col6" class="col_heading level0 col6" >quarter</th>
#       <th id="T_6264f_level0_col7" class="col_heading level0 col7" >year</th>
#       <th id="T_6264f_level0_col8" class="col_heading level0 col8" >week_of_year</th>
#       <th id="T_6264f_level0_col9" class="col_heading level0 col9" >day_of_year</th>
#       <th id="T_6264f_level0_col10" class="col_heading level0 col10" >time_of_day</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6264f_level0_row0" class="row_heading level0 row0" >2003-09-05 02:00:00</th>
#       <td id="T_6264f_row0_col0"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145354 entries, 2002-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   PJME_MW       145354 non-null  float64
#  1   hour          145354 non-null  int64
#  2   weekday       145354 non-null  int64
#  3   weekday_name  145354 non-null  category
#  4   month         145354 non-null  int64
#  5   month_name    145354 non-null  category
#  6   quarter       145354 non-null  int64
#  7   year          145354 non-null  int64
#  8   week_of_year  145354 non-null  UInt32
#  9   day_of_year   145354 non-null  int64
#  10  time_of_day   145354 non-null  category
# dtypes: UInt32(1), category(3), float64(1), int64(6)
# memory usage: 10.0 MB

# %% [markdown]
# <a name="correlation"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Investigating Correlation**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Visualize Correlation Between Features and Target**

# %%
def boxplot_correlation(df, feature_x, feature_y, order = None, palette = None):
	
	fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
	ax.set_facecolor('LightGray')
	
	sns.boxplot(data = df, 
				x = feature_x, 
				y = feature_y,
			    order = order,
			    palette = palette)
	
	x_name = str(df[feature_x].name)
	y_name = str(df[feature_y].name)
	
	ax.grid()
	plt.xlabel(x_name, color = 'white', fontsize = 15)
	plt.ylabel(y_name, color = 'white', fontsize = 15)
	plt.xticks(color='white'); plt.yticks(color='white');
	plt.title(f'Feature Correlation: {x_name.capitalize()} - {y_name.capitalize()}', 
			  fontsize = 20, pad = 20, color = 'white');

# %%
boxplot_correlation(df, 'hour', 'PJME_MW', 
					palette = colors)

# %%
daytimes = ['midnight', 'early_morning', 'late_morning', 'afternoon', 
			'evening', 'night']

boxplot_correlation(df, 'time_of_day', 'PJME_MW', 
					order = daytimes, palette = colors)

# %%
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July',
                  'August', 'September', 'October', 'November', 'December']

boxplot_correlation(df, 'month_name', 'PJME_MW', 
					order = months, palette = colors)

# %%
boxplot_correlation(df, 'quarter', 'PJME_MW',
				   palette = colors)

# %%
boxplot_correlation(df, 'week_of_year', 'PJME_MW',
				   palette = colors)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Converting `week_of_year` to float for model training**

# %%
df['week_of_year'] = df.week_of_year.astype(float)

# %% [markdown]
# <a name="lag_features"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Lag Features**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Forecasting Horizon & Lag Features**
# * Lag Features: telling the model to look back into the past, and use the target value for that many days back as a new feature fed into the model
# * in this case, it is a value from the energy usage column
# * we are saving this column as a `dict` called `target_map`
# * using 364 as the increment, because it is perfectly divisible by 7 and will line up days of the week
# * the forecast horizon cannot extend farther than the shortest lag chosen
# * using `map()` to map the values

# %%
def year_lags(df, target_column, lag_label_list):
	
	target_map = df[target_column].to_dict()
	inputs = lag_label_list.copy()
	
	for tup in inputs:
		df[tup[1]] = (df.index - pd.Timedelta(tup[0])).map(target_map)
	
	return df

# %%
lag_label_list = [('364 days', 'one_year'),
				  ('728 days', 'two_year'),
				  ('1092 days', 'three_year')]

# %%
df_lags = df.copy()
df_lags = year_lags(df_lags, 'PJME_MW', lag_label_list)

# %%
missing_values(df_lags[['one_year', 'two_year', 'three_year']])
# Out:
# <span style = 'display: block; width: 38%; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=3><text style=color:white>Columns and Missing Values						</text></font></b></style>
# <center><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>column name</th>
#       <th>missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>one_year</td>
#       <td>8755</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>two_year</td>
#       <td>17497</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>three_year</td>
#       <td>26237</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a name="splitting"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Splitting the Data**</font></span>
# * Because I noticed that I actually got better results training without the lag features added, I will be running each operation on both the data without lag features and with lag features for comparison.

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Traditional Train-Test Split**
# * training data will be up through 2014
# * test data will be everything following the 2014 training data ending

# %%
train_data = df.iloc[df.index < '01-01-2015']
test_data = df.iloc[df.index >= '01-01-2015']
train_data = pd.get_dummies(data=train_data, columns = ['time_of_day'])
test_data = pd.get_dummies(data=test_data, columns = ['time_of_day'])

# %%
train_data_lags = df_lags.iloc[df.index < '01-01-2015']
test_data_lags = df_lags.iloc[df.index >= '01-01-2015']
train_data_lags = pd.get_dummies(data=train_data_lags, columns = ['time_of_day'])
test_data_lags = pd.get_dummies(data=test_data_lags, columns = ['time_of_day'])

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Visualizing the Traditional Train-Test Split**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')
train_data.plot(ax = ax, label = 'Training Data', color = 'cyan');
test_data.plot(ax = ax, label = 'Testing Data', color = 'deeppink');
ax.grid()
ax.axvline('01-01-2015', color = 'yellow', ls = '--', linewidth = 3)
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white'); plt.yticks(color='white');
plt.title('Train-Test Split', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Defining Features & Targets**

# %%
features = ['hour', 'weekday', 'month', 'quarter', 'year', 
			'week_of_year', 'day_of_year', 'time_of_day_afternoon', 
			'time_of_day_early_morning', 'time_of_day_evening', 
			'time_of_day_late_morning', 'time_of_day_midnight', 
			'time_of_day_night']

features_lags = ['hour', 'weekday', 'month', 'quarter', 'year', 
			'week_of_year', 'day_of_year', 'time_of_day_afternoon', 
			'time_of_day_early_morning', 'time_of_day_evening', 
			'time_of_day_late_morning', 'time_of_day_midnight', 
			'time_of_day_night', 'one_year', 'two_year', 'three_year']
							 
target = "PJME_MW"

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Defining Training & Testing Data with Features**

# %%
train_in = train_data[features]
train_out = train_data[target]
test_in = test_data[features]
test_out = test_data[target]

# %%
train_in_lags = train_data_lags[features_lags]
train_out_lags = train_data_lags[target]
test_in_lags = test_data_lags[features_lags]
test_out_lags = test_data_lags[target]

# %% [markdown]
# <a name="model"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**The XGBoost Regressor Model**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Creating the Model (without lags)**

# %%
xgb_regressor = XGBRegressor(n_estimators = 1200,
							 learning_rate = 0.012, 
							 early_stopping_rounds = 44)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Fitting the Model (without lags)**

# %%
xgb_regressor.fit(train_in, train_out,
				 eval_set = [(train_in, train_out), 
							  (test_in, test_out)], 
				  verbose = 25)
# Out:
# [0]	validation_0-rmse:32538.11168	validation_1-rmse:31589.28081
# [25]	validation_0-rmse:24179.82571	validation_1-rmse:23230.85844
# [50]	validation_0-rmse:18029.80078	validation_1-rmse:17125.03390
# [75]	validation_0-rmse:13520.80540	validation_1-rmse:12668.91715
# [100]	validation_0-rmse:10235.57679	validation_1-rmse:9506.62622
# [125]	validation_0-rmse:7864.68556	validation_1-rmse:7303.57510
# [150]	validation_0-rmse:6181.91116	validation_1-rmse:5818.83418
# [175]	validation_0-rmse:5012.69635	validation_1-rmse:4874.41330
# [200]	validation_0-rmse:4219.37563	validation_1-rmse:4306.86936
# [225]	validation_0-rmse:3699.98218	validation_1-rmse:3983.86161
# [250]	validation_0-rmse:3365.56327	validation_1-rmse:3821.82708
# [275]	validation_0-rmse:3152.30039	validation_1-rmse:3746.22158
# [300]	validation_0-rmse:3009.99259	validation_1-rmse:3708.70681
# [325]	validation_0-rmse:2899.33655	validation_1-rmse:3697.82137
# [350]	validation_0-rmse:2820.73376	validation_1-rmse:3701.59534
# [375]	validation_0-rmse:2760.41753	validation_1-rmse:3714.77516
# [376]	validation_0-rmse:2757.56521	validation_1-rmse:3715.03038
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=44,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.012, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Fitting the Model (with lags)**

# %%
xgb_regressor_lags = XGBRegressor(n_estimators = 1200,
							 learning_rate = 0.012, 
							 early_stopping_rounds = 44)

# %%
xgb_regressor_lags.fit(train_in_lags, train_out_lags,
				 eval_set = [(train_in_lags, train_out_lags), 
							  (test_in_lags, test_out_lags)], 
				  verbose = 25)
# Out:
# [0]	validation_0-rmse:32538.37771	validation_1-rmse:31597.68259
# [25]	validation_0-rmse:24186.75617	validation_1-rmse:23478.21669
# [50]	validation_0-rmse:18043.14457	validation_1-rmse:17536.98201
# [75]	validation_0-rmse:13538.52268	validation_1-rmse:13219.62868
# [100]	validation_0-rmse:10258.41550	validation_1-rmse:10114.17478
# [125]	validation_0-rmse:7891.40920	validation_1-rmse:7909.37006
# [150]	validation_0-rmse:6207.18932	validation_1-rmse:6383.42793
# [175]	validation_0-rmse:5036.53259	validation_1-rmse:5367.42326
# [200]	validation_0-rmse:4247.14821	validation_1-rmse:4705.83983
# [225]	validation_0-rmse:3726.75174	validation_1-rmse:4316.07136
# [250]	validation_0-rmse:3394.44942	validation_1-rmse:4094.08970
# [275]	validation_0-rmse:3186.65178	validation_1-rmse:3972.57738
# [300]	validation_0-rmse:3055.03605	validation_1-rmse:3910.84523
# [325]	validation_0-rmse:2969.04758	validation_1-rmse:3885.87862
# [350]	validation_0-rmse:2905.30628	validation_1-rmse:3876.98696
# [375]	validation_0-rmse:2847.59802	validation_1-rmse:3882.97980
# [389]	validation_0-rmse:2820.36048	validation_1-rmse:3887.99289
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=44,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.012, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1200, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Feature Importance (without lags)**

# %%
feature_importance = pd.DataFrame(data = xgb_regressor.feature_importances_,
									index = xgb_regressor.feature_names_in_,
									columns = ['importance'])

feature_importance = feature_importance[feature_importance.importance > 0.0005]

multi([(feature_importance.sort_values('importance', ascending = False), 
		'Feature Importance (no lags)')], precision = 4)
# Out:
# <center><style type="text/css">
# #T_27858 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
# }
# </style>
# <table id="T_27858" style='display:inline-block'>
#   <caption>Feature Importance (no lags)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27858_level0_col0" class="col_heading level0 col0" >importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27858_level0_row0" class="row_heading level0 row0" >hour</th>
#       <td id="T_27858_row0_col0" class="data row0 col0" >0.4080</td>
#     </tr>
#     <tr>
#       <th id="T_27858_level0_row1" class="row_heading level0 row1" >month</th>
#       <td id="T_27858_row1_col0" class="data row1 col0" >0.1886</td>
#     </tr>
#     <tr>
#       <th id="T_27858_level0_row2" class="row_heading level0 row2" >weekday</th>
#       <td id="T_27858_row2_col0" class="data row2 col0" >0.1378</td>
#     </tr>
#     <tr>
#       <th id="T_27858_level0_row3" class="row_heading level0 row3" >day_of_year</th>
#       <td id="T_27858_row3_col0" class="data row3 col0" >0.1063</td>
#     </tr>
#     <tr>
#       <th id="T_27858_level0_row4" class="row_heading level0 row4" >time_of_day_evening</th>
#       <td id="T_27858_row4_col0" class="data row4 col0" >0.0626</td>
#     </tr>
#     <tr>
#       <th id="T_27858_level0_row5" class="row_heading level0 row5" >week_of_year</th>
#       <td id="T_27858_row5_col0" class="data row5 col0" >0.0517</td>
#     </tr>
#     <tr>
#       <th id="T_27858_level0_row6" class="row_heading level0 row6" >time_of_day_afternoon</th>
#       <td id="T_27858_row6_col0" class="data row6 col0" >0.0227</td>
#     </tr>
#     <tr>
#       <th id="T_27858_level0_row7" class="row_heading level0 row7" >year</th>
#       <td id="T_27858_row7_col0" class="data row7 col0" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_27858_level0_row8" class="row_heading level0 row8" >time_of_day_late_morning</th>
#       <td id="T_27858_row8_col0" class="data row8 col0" >0.0011</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Plotting Feature Importance (without lags)**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')

feature_importance.sort_values('importance').plot(kind = 'barh', 
												  color = 'cyan', 
												  ax = ax)
ax.grid()
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white', size = 13); plt.yticks(color='white', size = 13);
plt.title('Feature Importance Without Lags', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Feature Importance (with lags)**

# %%
feature_importance_lags = pd.DataFrame(data = xgb_regressor.feature_importances_,
									index = xgb_regressor.feature_names_in_,
									columns = ['importance'])

feature_importance_lags = feature_importance_lags[feature_importance_lags.importance > 0.0005]

multi([(feature_importance_lags.sort_values('importance', ascending = False), 
		'Feature Importance (with lags)')], precision = 4)
# Out:
# <center><style type="text/css">
# #T_4f99f caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 15px;
#   font-weight: bold;
# }
# </style>
# <table id="T_4f99f" style='display:inline-block'>
#   <caption>Feature Importance (with lags)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f99f_level0_col0" class="col_heading level0 col0" >importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f99f_level0_row0" class="row_heading level0 row0" >hour</th>
#       <td id="T_4f99f_row0_col0" class="data row0 col0" >0.4080</td>
#     </tr>
#     <tr>
#       <th id="T_4f99f_level0_row1" class="row_heading level0 row1" >month</th>
#       <td id="T_4f99f_row1_col0" class="data row1 col0" >0.1886</td>
#     </tr>
#     <tr>
#       <th id="T_4f99f_level0_row2" class="row_heading level0 row2" >weekday</th>
#       <td id="T_4f99f_row2_col0" class="data row2 col0" >0.1378</td>
#     </tr>
#     <tr>
#       <th id="T_4f99f_level0_row3" class="row_heading level0 row3" >day_of_year</th>
#       <td id="T_4f99f_row3_col0" class="data row3 col0" >0.1063</td>
#     </tr>
#     <tr>
#       <th id="T_4f99f_level0_row4" class="row_heading level0 row4" >time_of_day_evening</th>
#       <td id="T_4f99f_row4_col0" class="data row4 col0" >0.0626</td>
#     </tr>
#     <tr>
#       <th id="T_4f99f_level0_row5" class="row_heading level0 row5" >week_of_year</th>
#       <td id="T_4f99f_row5_col0" class="data row5 col0" >0.0517</td>
#     </tr>
#     <tr>
#       <th id="T_4f99f_level0_row6" class="row_heading level0 row6" >time_of_day_afternoon</th>
#       <td id="T_4f99f_row6_col0" class="data row6 col0" >0.0227</td>
#     </tr>
#     <tr>
#       <th id="T_4f99f_level0_row7" class="row_heading level0 row7" >year</th>
#       <td id="T_4f99f_row7_col0" class="data row7 col0" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_4f99f_level0_row8" class="row_heading level0 row8" >time_of_day_late_morning</th>
#       <td id="T_4f99f_row8_col0" class="data row8 col0" >0.0011</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Plotting Feature Importance (with lags)**

# %%
fig, ax = plt.subplots(figsize = (13, 7), facecolor = '#333333')
ax.set_facecolor('#444444')

feature_importance_lags.sort_values('importance').plot(kind = 'barh', 
												  color = 'cyan', 
												  ax = ax)
ax.grid()
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white', size = 13); plt.yticks(color='white', size = 13);
plt.title('Feature Importance with Lags', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <a name="traditional_results"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Results with Traditional Train-Test Split**</font></span>
# * Because there is no benefit to having the lag data added, for the remainder of the project, I will be working with only the data without lags added.

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Predicting with Test Data**

# %%
test_data['prediction'] = xgb_regressor.predict(test_in)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Merging Predictions into Original DF**

# %%
df = df.merge(test_data['prediction'], 
			  how = 'left', 
			  left_index = True,
			  right_index = True)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Plotting Predictions vs Original Data**

# %%
plt.figure(facecolor = '#333333');
ax = df['PJME_MW'].plot(figsize = (13, 7), color = 'cyan');
ax.set_facecolor('#444444');
df['prediction'].plot(ax = ax, style = '.', color = 'deeppink');
plt.legend();
ax.grid()
plt.xlabel('years', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.xticks(color='white', size = 13); plt.yticks(color='white', size = 13);
plt.title('Train-Test Split', fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()
ax.set_title('Actual Data vs Predicted', color = 'white', size = 22, pad = 20);

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Predictions vs Targets: One Week Excerpt**

# %%
plt.figure(figsize = (13, 7), facecolor = '#333333')
ax = df.loc[(df.index > '04-01-2018') \
			& (df.index <= '04-08-2018')]\
			['PJME_MW'].plot(color = 'cyan', linewidth = 3);
df.loc[(df.index > '04-01-2018') \
			& (df.index <= '04-08-2018')]\
			['prediction'].plot(style = '.', color = 'yellow', markersize = 12);
ax.set_facecolor('#444444')
plt.legend();
ax.grid()
plt.xlabel('days', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Training Data vs Predictions: 1 Week Excerpt', fontsize = 20, pad = 20, color = 'white');
plt.legend(fontsize = 15, labelcolor = 'white', facecolor = '#333333');

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Prediction Accuracy**

# %%
pred_actual = df.loc[df.prediction.notna()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[296], line 1
# ----> 1 pred_actual = df.loc[df.prediction.notna()]
#
# File ~/opt/anaconda3/envs/stock_lstm_tutorials/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'prediction'

# %%
def get_accuracy(df, pred_col, actual_col):
	from sklearn.metrics import mean_squared_error
	df = df.copy()
	
	df['abs_acc'] = (1 - (abs(df[actual_col] - 
								   df[pred_col]) / df[actual_col])) * 100
	
	range_diff = np.max(df[actual_col]) - np.min(df[actual_col])
	
	df['rel_acc'] = (1 - (abs(df[actual_col] - 
								   df[pred_col]) / range_diff)) * 100 
	
	range_std = np.std(df[actual_col])
	
	df['sharpe'] = (abs(df[actual_col] - 
								   df[pred_col]) / range_std)
	
	rmse = np.sqrt(mean_squared_error(df[actual_col], 
										df[pred_col]))
	
	results = pd.Series([f"{rmse:,.2f}", 
						 f"{df['abs_acc'].mean():.2f}%",
						 f"{df['rel_acc'].mean():.2f}%",
						 f"{df['sharpe'].mean():.2f}"], 
						index = ['Average RMSE', 
								 'Average Absolute Accuracy', 
								 'Average Relative Accuracy',
								 'Average Sharpe Ratio'],
						name = "Resulting Metrics")
	
	see(results, 'Overall Metrics for Accuracy and Model Performance')

	return df

# %%
pred_actual = get_accuracy(pred_actual, 'PJME_MW', 'prediction')

head_tail_horz(pred_actual[['PJME_MW', 'prediction', 'abs_acc', 
							'rel_acc', 'sharpe']], 5, 'Predictions vs Actual Targets')
# Out:
# <span style = 'display: block; width: 500.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>Overall Metrics for Accuracy and Model Performance						</text></font></b></style>
# <center><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Resulting Metrics</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Average RMSE</th>
#       <td>3,696.84</td>
#     </tr>
#     <tr>
#       <th>Average Absolute Accuracy</th>
#       <td>91.34%</td>
#     </tr>
#     <tr>
#       <th>Average Relative Accuracy</th>
#       <td>88.49%</td>
#     </tr>
#     <tr>
#       <th>Average Sharpe Ratio</th>
#       <td>0.54</td>
#     </tr>
#   </tbody>
# </table>
# <span style = 'display: block; width: 290.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>Predictions vs Actual Targets						</text></font></b></style>
# <center><style type="text/css">
# #T_ba0f3 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_ba0f3" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba0f3_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_ba0f3_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_ba0f3_level0_col2" class="col_heading level0 col2" >abs_acc</th>
#       <th id="T_ba0f3_level0_col3" class="col_heading level0 col3" >rel_acc</th>
#       <th id="T_ba0f3_level0_col4" class="col_heading level0 col4" >sharpe</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba0f3_level0_row0" class="row_heading level0 row0" >2015-01-01</th>
#       <td id="T_ba0f3_row0_col0" class="data row0 col0" >32,802.00</td>
#       <td id="T_ba0f3_row0_col1" class="data row0 col1" >32,303.10</td>
#       <td id="T_ba0f3_row0_col2" class="data row0 col2" >98.46</td>
#       <td id="T_ba0f3_row0_col3" class="data row0 col3" >97.92</td>
#       <td id="T_ba0f3_row0_col4" class="data row0 col4" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_ba0f3_level0_row1" class="row_heading level0 row1" >2015-01-01</th>
#       <td id="T_ba0f3_row1_col0" class="data row1 col0" >31,647.00</td>
#       <td id="T_ba0f3_row1_col1" class="data row1 col1" >31,252.85</td>
#       <td id="T_ba0f3_row1_col2" class="data row1 col2" >98.74</td>
#       <td id="T_ba0f3_row1_col3" class="data row1 col3" >98.35</td>
#       <td id="T_ba0f3_row1_col4" class="data row1 col4" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_ba0f3_level0_row2" class="row_heading level0 row2" >2015-01-01</th>
#       <td id="T_ba0f3_row2_col0" class="data row2 col0" >30,755.00</td>
#       <td id="T_ba0f3_row2_col1" class="data row2 col1" >30,942.48</td>
#       <td id="T_ba0f3_row2_col2" class="data row2 col2" >99.39</td>
#       <td id="T_ba0f3_row2_col3" class="data row2 col3" >99.22</td>
#       <td id="T_ba0f3_row2_col4" class="data row2 col4" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_ba0f3_level0_row3" class="row_heading level0 row3" >2015-01-01</th>
#       <td id="T_ba0f3_row3_col0" class="data row3 col0" >30,189.00</td>
#       <td id="T_ba0f3_row3_col1" class="data row3 col1" >31,155.66</td>
#       <td id="T_ba0f3_row3_col2" class="data row3 col2" >96.90</td>
#       <td id="T_ba0f3_row3_col3" class="data row3 col3" >95.96</td>
#       <td id="T_ba0f3_row3_col4" class="data row3 col4" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_ba0f3_level0_row4" class="row_heading level0 row4" >2015-01-01</th>
#       <td id="T_ba0f3_row4_col0" class="data row4 col0" >29,890.00</td>
#       <td id="T_ba0f3_row4_col1" class="data row4 col1" >31,155.66</td>
#       <td id="T_ba0f3_row4_col2" class="data row4 col2" >95.94</td>
#       <td id="T_ba0f3_row4_col3" class="data row4 col3" >94.71</td>
#       <td id="T_ba0f3_row4_col4" class="data row4 col4" >0.25</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_3b0b5 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_3b0b5" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b0b5_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_3b0b5_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_3b0b5_level0_col2" class="col_heading level0 col2" >abs_acc</th>
#       <th id="T_3b0b5_level0_col3" class="col_heading level0 col3" >rel_acc</th>
#       <th id="T_3b0b5_level0_col4" class="col_heading level0 col4" >sharpe</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b0b5_level0_row0" class="row_heading level0 row0" >2018-08-02</th>
#       <td id="T_3b0b5_row0_col0" class="data row0 col0" >44,057.00</td>
#       <td id="T_3b0b5_row0_col1" class="data row0 col1" >41,007.88</td>
#       <td id="T_3b0b5_row0_col2" class="data row0 col2" >92.56</td>
#       <td id="T_3b0b5_row0_col3" class="data row0 col3" >87.27</td>
#       <td id="T_3b0b5_row0_col4" class="data row0 col4" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_3b0b5_level0_row1" class="row_heading level0 row1" >2018-08-02</th>
#       <td id="T_3b0b5_row1_col0" class="data row1 col0" >43,256.00</td>
#       <td id="T_3b0b5_row1_col1" class="data row1 col1" >40,422.38</td>
#       <td id="T_3b0b5_row1_col2" class="data row1 col2" >92.99</td>
#       <td id="T_3b0b5_row1_col3" class="data row1 col3" >88.17</td>
#       <td id="T_3b0b5_row1_col4" class="data row1 col4" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_3b0b5_level0_row2" class="row_heading level0 row2" >2018-08-02</th>
#       <td id="T_3b0b5_row2_col0" class="data row2 col0" >41,552.00</td>
#       <td id="T_3b0b5_row2_col1" class="data row2 col1" >38,925.79</td>
#       <td id="T_3b0b5_row2_col2" class="data row2 col2" >93.25</td>
#       <td id="T_3b0b5_row2_col3" class="data row2 col3" >89.03</td>
#       <td id="T_3b0b5_row2_col4" class="data row2 col4" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_3b0b5_level0_row3" class="row_heading level0 row3" >2018-08-02</th>
#       <td id="T_3b0b5_row3_col0" class="data row3 col0" >38,500.00</td>
#       <td id="T_3b0b5_row3_col1" class="data row3 col1" >35,987.53</td>
#       <td id="T_3b0b5_row3_col2" class="data row3 col2" >93.02</td>
#       <td id="T_3b0b5_row3_col3" class="data row3 col3" >89.51</td>
#       <td id="T_3b0b5_row3_col4" class="data row3 col4" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_3b0b5_level0_row4" class="row_heading level0 row4" >2018-08-03</th>
#       <td id="T_3b0b5_row4_col0" class="data row4 col0" >35,486.00</td>
#       <td id="T_3b0b5_row4_col1" class="data row4 col1" >31,573.22</td>
#       <td id="T_3b0b5_row4_col2" class="data row4 col2" >87.61</td>
#       <td id="T_3b0b5_row4_col3" class="data row4 col3" >83.66</td>
#       <td id="T_3b0b5_row4_col4" class="data row4 col4" >0.77</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Plotting the Sharpe Ratio**

# %%
plt.figure(figsize = (13, 7), facecolor = '#333333')
ax = plt.axes()
pred_actual.sharpe.plot(kind="hist", 
						bins=100, 
						color = 'cyan',
						edgecolor = 'white',  
						ax = ax)
ax.set_facecolor('#444444')
plt.legend();
ax.grid()
plt.xlabel('sharpe ratio', color = 'white', fontsize = 15)
plt.ylabel('count', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Overall Distribution of Sharpe Ratio Metrics', 
		  fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Daily Error - Investigating the Days with the Highest and Lowest Error**

# %%
def get_daily_error(df, actual_col, pred_col, num_examples, 
					ascending = False):
	
	temp = df[[actual_col, pred_col]].copy()
	temp['date'] = temp.index.strftime('%A, %b %d, %Y')
	temp['error'] = np.abs(df[actual_col] - df[pred_col])
	
	results = temp.sort_values("error", ascending = ascending)
	
	error_style = {'error': [{'selector': '',
						      'props': [('color', 'red'),
										('font-weight', 'bold'),
										('padding-right', '15px'),
								        ('padding-left', '15px')]}],
				   'date': [{'selector': 'td',
						     'props': [('color', 'blue'),
									   ('font-weight', 'bold'),
									   ('padding-right', '15px'),
								       ('padding-left', '15px')]}],
				   'prediction': [{'selector': 'td',
						     'props': [('padding-right', '25px'),
								       ('padding-left', '15px')]}]}
	
	
	if ascending == True:
		pretty(f'Daily error for the {num_examples} days with the lowest error:',
			   fontsize = 4)
	else:
		pretty(f'Daily error for the {num_examples} days with the highest error:',
			   fontsize = 4)
	
	return results[['date', 
					'error', 
					pred_col, 
					actual_col]].head(num_examples).style.hide(axis='index')\
						.set_table_styles(error_style)\
						.format(precision=3, thousands=",")

# %%
get_daily_error(pred_actual, 'PJME_MW', 'prediction', 10)
# Out:
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=4><text style=color:white>Daily error for the 10 days with the highest error:                                </text></font></b></style>
# <style type="text/css">
# #T_ec045 .col1 {
#   color: red;
#   font-weight: bold;
#   padding-right: 15px;
#   padding-left: 15px;
# }
# #T_ec045 td.col0 {
#   color: blue;
#   font-weight: bold;
#   padding-right: 15px;
#   padding-left: 15px;
# }
# #T_ec045 td.col2 {
#   padding-right: 25px;
#   padding-left: 15px;
# }
# </style>
# <table id="T_ec045">
#   <thead>
#     <tr>
#       <th id="T_ec045_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_ec045_level0_col1" class="col_heading level0 col1" >error</th>
#       <th id="T_ec045_level0_col2" class="col_heading level0 col2" >prediction</th>
#       <th id="T_ec045_level0_col3" class="col_heading level0 col3" >PJME_MW</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ec045_row0_col0" class="data row0 col0" >Saturday, Aug 13, 2016</td>
#       <td id="T_ec045_row0_col1" class="data row0 col1" >20,142.438</td>
#       <td id="T_ec045_row0_col2" class="data row0 col2" >34,756.562</td>
#       <td id="T_ec045_row0_col3" class="data row0 col3" >54,899.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row1_col0" class="data row1 col0" >Saturday, Aug 13, 2016</td>
#       <td id="T_ec045_row1_col1" class="data row1 col1" >19,737.535</td>
#       <td id="T_ec045_row1_col2" class="data row1 col2" >35,378.465</td>
#       <td id="T_ec045_row1_col3" class="data row1 col3" >55,116.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row2_col0" class="data row2 col0" >Saturday, Aug 13, 2016</td>
#       <td id="T_ec045_row2_col1" class="data row2 col1" >19,659.191</td>
#       <td id="T_ec045_row2_col2" class="data row2 col2" >35,290.809</td>
#       <td id="T_ec045_row2_col3" class="data row2 col3" >54,950.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row3_col0" class="data row3 col0" >Saturday, Aug 13, 2016</td>
#       <td id="T_ec045_row3_col1" class="data row3 col1" >19,528.438</td>
#       <td id="T_ec045_row3_col2" class="data row3 col2" >34,756.562</td>
#       <td id="T_ec045_row3_col3" class="data row3 col3" >54,285.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row4_col0" class="data row4 col0" >Saturday, Aug 13, 2016</td>
#       <td id="T_ec045_row4_col1" class="data row4 col1" >19,038.195</td>
#       <td id="T_ec045_row4_col2" class="data row4 col2" >34,514.805</td>
#       <td id="T_ec045_row4_col3" class="data row4 col3" >53,553.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row5_col0" class="data row5 col0" >Saturday, Aug 13, 2016</td>
#       <td id="T_ec045_row5_col1" class="data row5 col1" >18,879.059</td>
#       <td id="T_ec045_row5_col2" class="data row5 col2" >35,189.941</td>
#       <td id="T_ec045_row5_col3" class="data row5 col3" >54,069.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row6_col0" class="data row6 col0" >Sunday, Aug 14, 2016</td>
#       <td id="T_ec045_row6_col1" class="data row6 col1" >18,766.137</td>
#       <td id="T_ec045_row6_col2" class="data row6 col2" >34,279.863</td>
#       <td id="T_ec045_row6_col3" class="data row6 col3" >53,046.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row7_col0" class="data row7 col0" >Saturday, Sep 10, 2016</td>
#       <td id="T_ec045_row7_col1" class="data row7 col1" >18,651.844</td>
#       <td id="T_ec045_row7_col2" class="data row7 col2" >31,601.156</td>
#       <td id="T_ec045_row7_col3" class="data row7 col3" >50,253.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row8_col0" class="data row8 col0" >Sunday, Aug 14, 2016</td>
#       <td id="T_ec045_row8_col1" class="data row8 col1" >18,642.191</td>
#       <td id="T_ec045_row8_col2" class="data row8 col2" >35,290.809</td>
#       <td id="T_ec045_row8_col3" class="data row8 col3" >53,933.000</td>
#     </tr>
#     <tr>
#       <td id="T_ec045_row9_col0" class="data row9 col0" >Saturday, Aug 13, 2016</td>
#       <td id="T_ec045_row9_col1" class="data row9 col1" >18,467.637</td>
#       <td id="T_ec045_row9_col2" class="data row9 col2" >33,997.363</td>
#       <td id="T_ec045_row9_col3" class="data row9 col3" >52,465.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
get_daily_error(pred_actual, 'PJME_MW', 'prediction', 10,
			   ascending = True)
# Out:
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=4><text style=color:white>Daily error for the 10 days with the lowest error:                                </text></font></b></style>
# <style type="text/css">
# #T_53c17 .col1 {
#   color: red;
#   font-weight: bold;
#   padding-right: 15px;
#   padding-left: 15px;
# }
# #T_53c17 td.col0 {
#   color: blue;
#   font-weight: bold;
#   padding-right: 15px;
#   padding-left: 15px;
# }
# #T_53c17 td.col2 {
#   padding-right: 25px;
#   padding-left: 15px;
# }
# </style>
# <table id="T_53c17">
#   <thead>
#     <tr>
#       <th id="T_53c17_level0_col0" class="col_heading level0 col0" >date</th>
#       <th id="T_53c17_level0_col1" class="col_heading level0 col1" >error</th>
#       <th id="T_53c17_level0_col2" class="col_heading level0 col2" >prediction</th>
#       <th id="T_53c17_level0_col3" class="col_heading level0 col3" >PJME_MW</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_53c17_row0_col0" class="data row0 col0" >Thursday, Aug 03, 2017</td>
#       <td id="T_53c17_row0_col1" class="data row0 col1" >0.170</td>
#       <td id="T_53c17_row0_col2" class="data row0 col2" >31,646.170</td>
#       <td id="T_53c17_row0_col3" class="data row0 col3" >31,646.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row1_col0" class="data row1 col0" >Tuesday, Nov 22, 2016</td>
#       <td id="T_53c17_row1_col1" class="data row1 col1" >0.285</td>
#       <td id="T_53c17_row1_col2" class="data row1 col2" >31,488.715</td>
#       <td id="T_53c17_row1_col3" class="data row1 col3" >31,489.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row2_col0" class="data row2 col0" >Wednesday, May 30, 2018</td>
#       <td id="T_53c17_row2_col1" class="data row2 col1" >0.686</td>
#       <td id="T_53c17_row2_col2" class="data row2 col2" >31,844.686</td>
#       <td id="T_53c17_row2_col3" class="data row2 col3" >31,844.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row3_col0" class="data row3 col0" >Thursday, Nov 16, 2017</td>
#       <td id="T_53c17_row3_col1" class="data row3 col1" >0.859</td>
#       <td id="T_53c17_row3_col2" class="data row3 col2" >33,211.859</td>
#       <td id="T_53c17_row3_col3" class="data row3 col3" >33,211.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row4_col0" class="data row4 col0" >Tuesday, Feb 10, 2015</td>
#       <td id="T_53c17_row4_col1" class="data row4 col1" >0.863</td>
#       <td id="T_53c17_row4_col2" class="data row4 col2" >35,364.137</td>
#       <td id="T_53c17_row4_col3" class="data row4 col3" >35,365.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row5_col0" class="data row5 col0" >Friday, Jul 07, 2017</td>
#       <td id="T_53c17_row5_col1" class="data row5 col1" >0.875</td>
#       <td id="T_53c17_row5_col2" class="data row5 col2" >38,732.125</td>
#       <td id="T_53c17_row5_col3" class="data row5 col3" >38,733.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row6_col0" class="data row6 col0" >Sunday, Mar 25, 2018</td>
#       <td id="T_53c17_row6_col1" class="data row6 col1" >0.883</td>
#       <td id="T_53c17_row6_col2" class="data row6 col2" >27,661.883</td>
#       <td id="T_53c17_row6_col3" class="data row6 col3" >27,661.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row7_col0" class="data row7 col0" >Thursday, Nov 02, 2017</td>
#       <td id="T_53c17_row7_col1" class="data row7 col1" >0.916</td>
#       <td id="T_53c17_row7_col2" class="data row7 col2" >27,613.916</td>
#       <td id="T_53c17_row7_col3" class="data row7 col3" >27,613.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row8_col0" class="data row8 col0" >Saturday, Dec 09, 2017</td>
#       <td id="T_53c17_row8_col1" class="data row8 col1" >1.172</td>
#       <td id="T_53c17_row8_col2" class="data row8 col2" >27,940.172</td>
#       <td id="T_53c17_row8_col3" class="data row8 col3" >27,939.000</td>
#     </tr>
#     <tr>
#       <td id="T_53c17_row9_col0" class="data row9 col0" >Tuesday, Mar 31, 2015</td>
#       <td id="T_53c17_row9_col1" class="data row9 col1" >1.324</td>
#       <td id="T_53c17_row9_col2" class="data row9 col2" >30,971.324</td>
#       <td id="T_53c17_row9_col3" class="data row9 col3" >30,970.000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <a name="cross_validation"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Training the Model Using Cross Validation**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**What is Cross Validation?**
# * using sklearn `TimeSeriesSplit()`
# * test size is 1 year of hourly records
# * a gap of 24 puts a 1 day gap between the end of a training set and beginning of a test set
# * must be sure time series data is sorted so that the time series split will work

# %%
time_series_split = TimeSeriesSplit(n_splits = 5,
								    test_size = (24 * 365 * 1),
								    gap = 24)

df = df.sort_index()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**This creates a time series split generator object**
# * this object will be applied across the data
# * it will loop over the data 5 times

# %%
time_series_split
# Out:
# TimeSeriesSplit(gap=24, max_train_size=None, n_splits=5, test_size=8760)

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Visualizing the `TimeSeriesSplit()` process**
#
# * for each fold, the model goes back and tests the testing data in 1 year increments, independently from the rest of the testing data
# * this is a very good approach when the dataset has a large number of records

# %%
for train_index, validation_index in time_series_split.split(df):
	break
pretty(train_index, 'Indices of training data:')
pretty(validation_index, 'Indices of validation data:'); sp()
# Out:
# <span style = 'line-height: 2;                                 background: #ececec; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:#111111>Indices of training data:                                </text></font></b></style>
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>[     0      1      2 ... 101533 101534 101535]                                </text></font></b></style>
# <span style = 'line-height: 2;                                 background: #ececec; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:#111111>Indices of validation data:                                </text></font></b></style>
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>[101560 101561 101562 ... 110317 110318 110319]                                </text></font></b></style>

# %%
fig, axs = plt.subplots(5, 1, figsize = (13, 10),
					   sharex = True, facecolor = "#222222")

split = 0
for train_index, validation_index in time_series_split.split(df):
	training = df.iloc[train_index]
	validation = df.iloc[validation_index]
	
	ax = axs[fold]
	ax.set_facecolor('#444444')
	ax.set_title(f'Training & Testing splot for split no. {split}', 
				 fontsize = 15, color = 'white')
	ax.tick_params(color = 'white', labelcolor = 'white')

	training['PJME_MW'].plot(ax = ax,
							label = 'Training Set',
							color = 'cyan')
	validation['PJME_MW'].plot(ax = ax,
							label = 'Validation Set',
							  color = 'deeppink')

	axs[fold].axvline(validation.index.min(), 
					  color = 'white', ls = "--", linewidth = 3)
	
	axs[0].legend(fontsize=16, facecolor = '#222222', labelcolor = 'white')

	split += 1

plt.suptitle('5 Different Folds of Cross Validation', color = 'white', fontsize = 24)
plt.tight_layout()

# %%
df = data.query('PJME_MW > 18_500').copy()

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Training with Cross Validation**
# * this will repeat the steps above in order to now train with cross validation and the `TimeSeriesSplit()` method

# %%
def cross_validation_train(df, target_column,
							lags = False, lag_label_list = None, 
							splits = 5, test_size = (24 * 365 * 1),
							gap = 24, base_score = 0.5, booster = 'gbtree',
							n_estimators = 1200, early_stopping_rounds = 50,
							objective = 'reg:squarederror', max_depth = 3,
							learning_rate = 0.01, verbose = 25):
	
	from sklearn.metrics import mean_squared_error
	from sklearn.model_selection import TimeSeriesSplit
	
	# ................ Establishing Features & Targets ................ #
	
	df = featurize_datetime_index(df)
	target = target_column
	
	# ................ Lag Features & Feature Cleanup ................. #
	
	if lags:
		df = year_lags(df, target_column, lag_label_list)
		features = list(df.columns)

	else:
		features = list(df.columns)

	features.remove('weekday_name')
	features.remove('month_name')
	features.remove('time_of_day')
	features.remove(target)
		
	# ................. Correcting Datatypes for Model ................ #
		
	df['week_of_year'] = df.week_of_year.astype(float)
	
	# .................. Setting Up Cross-Validation .................. #
		
	split = 1
	prediction_log = []
	target_log = []
	rmse_log = []
		
	df = df.sort_index()
	time_series_split = TimeSeriesSplit(n_splits = splits,
								    test_size = test_size,
								    gap = gap)
	
	# ............... Running Cross-Validation Training ............... #
	
	for train_index, validation_index in time_series_split.split(df):
		pretty(f'Training round:  {split} / {splits}')
		training = df.iloc[train_index]
		validation = df.iloc[validation_index]
		
		train_in = training[features]
		train_out = training[target]
		test_in = validation[features]
		test_out = validation[target]
		
		model = XGBRegressor(base_score = base_score,
							   booster = booster,
							   n_estimators = n_estimators,
							   early_stopping_rounds = early_stopping_rounds,
							   objective = objective,
							   max_depth = max_depth,
							   learning_rate = learning_rate)
		

		model.fit(train_in, train_out,
				 eval_set = [(train_in, train_out), 
							  (test_in, test_out)], 
				  verbose = verbose)
		
		targets = list(test_out)
		target_log += targets
		
		prediction = model.predict(test_in)
		prediction_log += list(prediction)
		
		rmse = np.sqrt(mean_squared_error(test_out, prediction))
		rmse_log.append((f'split {split}', rmse))
		
		split += 1
		
	# ............. Compiling Training & Testing Results .............. #
		
	results = pd.DataFrame(pd.concat([pd.Series(prediction_log), 
									  pd.Series(target_log)],
									 axis = 1))
	results.columns = ['prediction', 'actual']
	
	pred_actual = get_accuracy(results, 'actual', 'prediction')
	
	print('')
	
	head_tail_horz(pred_actual[['actual', 'prediction', 'abs_acc', 
							'rel_acc', 'sharpe']], 5, 'Predictions vs Actual Targets')
	
	return pred_actual, rmse_log

# Figure out how to make a log for accuracy as above

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Cross-Validation Results without Lag Features**

# %%
cross_results, rmses = cross_validation_train(df, 
									   target_column = "PJME_MW",
									   learning_rate = 0.012, 
									   verbose = 500,
									   splits = 16)
# Out:
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  1 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:31723.90046	validation_1-rmse:32036.34632
# [217]	validation_0-rmse:3647.14382	validation_1-rmse:6509.72283
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  2 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:31945.71700	validation_1-rmse:32437.33465
# [500]	validation_0-rmse:2698.36874	validation_1-rmse:3219.56255
# [665]	validation_0-rmse:2560.11143	validation_1-rmse:3181.55373
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  3 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32133.13362	validation_1-rmse:32792.61666
# [500]	validation_0-rmse:2824.72080	validation_1-rmse:3627.98420
# [1000]	validation_0-rmse:2538.44798	validation_1-rmse:3513.16299
# [1199]	validation_0-rmse:2454.29383	validation_1-rmse:3499.52072
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  4 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32310.98939	validation_1-rmse:33471.58198
# [500]	validation_0-rmse:2908.75384	validation_1-rmse:3453.75502
# [1000]	validation_0-rmse:2646.70475	validation_1-rmse:3318.65070
# [1199]	validation_0-rmse:2582.61833	validation_1-rmse:3281.13626
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  5 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32564.21370	validation_1-rmse:33075.84705
# [500]	validation_0-rmse:2932.78641	validation_1-rmse:3368.29789
# [525]	validation_0-rmse:2908.61563	validation_1-rmse:3371.82685
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  6 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32659.23199	validation_1-rmse:33680.56766
# [500]	validation_0-rmse:3016.07147	validation_1-rmse:3332.70258
# [784]	validation_0-rmse:2846.13862	validation_1-rmse:3258.98043
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  7 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32818.71144	validation_1-rmse:32194.49436
# [368]	validation_0-rmse:3231.97943	validation_1-rmse:3167.47601
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  8 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32736.27282	validation_1-rmse:33075.19132
# [500]	validation_0-rmse:3069.84256	validation_1-rmse:3678.43746
# [547]	validation_0-rmse:3033.89543	validation_1-rmse:3687.11020
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  9 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32775.09367	validation_1-rmse:33332.18798
# [500]	validation_0-rmse:3126.55909	validation_1-rmse:3551.16025
# [1000]	validation_0-rmse:2902.59141	validation_1-rmse:3296.85673
# [1199]	validation_0-rmse:2844.04463	validation_1-rmse:3256.02066
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  10 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32833.63672	validation_1-rmse:31633.79300
# [360]	validation_0-rmse:3337.97405	validation_1-rmse:3259.34965
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  11 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32722.43961	validation_1-rmse:32058.83985
# [500]	validation_0-rmse:3171.48096	validation_1-rmse:3337.00488
# [1000]	validation_0-rmse:2943.55291	validation_1-rmse:3182.44254
# [1199]	validation_0-rmse:2889.37879	validation_1-rmse:3146.31617
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  12 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32669.41010	validation_1-rmse:31891.05445
# [438]	validation_0-rmse:3231.32111	validation_1-rmse:3714.62815
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  13 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32609.24263	validation_1-rmse:32074.04540
# [500]	validation_0-rmse:3212.91887	validation_1-rmse:3562.91633
# [1000]	validation_0-rmse:3012.69128	validation_1-rmse:3418.09961
# [1077]	validation_0-rmse:2986.90047	validation_1-rmse:3415.14818
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  14 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32568.44596	validation_1-rmse:31011.13896
# [386]	validation_0-rmse:3361.72932	validation_1-rmse:3539.05088
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  15 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32466.02041	validation_1-rmse:31407.06551
# [500]	validation_0-rmse:3239.93139	validation_1-rmse:3875.01443
# [1000]	validation_0-rmse:3043.11060	validation_1-rmse:3761.44533
# [1011]	validation_0-rmse:3040.82773	validation_1-rmse:3762.22775
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  16 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32399.90711	validation_1-rmse:31396.24584
# [500]	validation_0-rmse:3269.86376	validation_1-rmse:3909.74871
# [734]	validation_0-rmse:3158.37189	validation_1-rmse:3885.78805
# <span style = 'display: block; width: 500.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>Overall Metrics for Accuracy and Model Performance						</text></font></b></style>
# <center><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Resulting Metrics</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Average RMSE</th>
#       <td>3,654.62</td>
#     </tr>
#     <tr>
#       <th>Average Absolute Accuracy</th>
#       <td>91.53%</td>
#     </tr>
#     <tr>
#       <th>Average Relative Accuracy</th>
#       <td>90.37%</td>
#     </tr>
#     <tr>
#       <th>Average Sharpe Ratio</th>
#       <td>0.50</td>
#     </tr>
#   </tbody>
# </table>
# <span style = 'display: block; width: 290.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>Predictions vs Actual Targets						</text></font></b></style>
# <center><style type="text/css">
# #T_a8055 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_a8055" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8055_level0_col0" class="col_heading level0 col0" >actual</th>
#       <th id="T_a8055_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_a8055_level0_col2" class="col_heading level0 col2" >abs_acc</th>
#       <th id="T_a8055_level0_col3" class="col_heading level0 col3" >rel_acc</th>
#       <th id="T_a8055_level0_col4" class="col_heading level0 col4" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8055_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8055_row0_col0" class="data row0 col0" >48,920.00</td>
#       <td id="T_a8055_row0_col1" class="data row0 col1" >43,241.39</td>
#       <td id="T_a8055_row0_col2" class="data row0 col2" >86.87</td>
#       <td id="T_a8055_row0_col3" class="data row0 col3" >79.95</td>
#       <td id="T_a8055_row0_col4" class="data row0 col4" >1.05</td>
#     </tr>
#     <tr>
#       <th id="T_a8055_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8055_row1_col0" class="data row1 col0" >50,389.00</td>
#       <td id="T_a8055_row1_col1" class="data row1 col1" >43,278.83</td>
#       <td id="T_a8055_row1_col2" class="data row1 col2" >83.57</td>
#       <td id="T_a8055_row1_col3" class="data row1 col3" >74.89</td>
#       <td id="T_a8055_row1_col4" class="data row1 col4" >1.32</td>
#     </tr>
#     <tr>
#       <th id="T_a8055_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8055_row2_col0" class="data row2 col0" >51,295.00</td>
#       <td id="T_a8055_row2_col1" class="data row2 col1" >43,278.83</td>
#       <td id="T_a8055_row2_col2" class="data row2 col2" >81.48</td>
#       <td id="T_a8055_row2_col3" class="data row2 col3" >71.69</td>
#       <td id="T_a8055_row2_col4" class="data row2 col4" >1.48</td>
#     </tr>
#     <tr>
#       <th id="T_a8055_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8055_row3_col0" class="data row3 col0" >51,623.00</td>
#       <td id="T_a8055_row3_col1" class="data row3 col1" >43,278.83</td>
#       <td id="T_a8055_row3_col2" class="data row3 col2" >80.72</td>
#       <td id="T_a8055_row3_col3" class="data row3 col3" >70.53</td>
#       <td id="T_a8055_row3_col4" class="data row3 col4" >1.54</td>
#     </tr>
#     <tr>
#       <th id="T_a8055_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8055_row4_col0" class="data row4 col0" >51,517.00</td>
#       <td id="T_a8055_row4_col1" class="data row4 col1" >43,278.83</td>
#       <td id="T_a8055_row4_col2" class="data row4 col2" >80.96</td>
#       <td id="T_a8055_row4_col3" class="data row4 col3" >70.91</td>
#       <td id="T_a8055_row4_col4" class="data row4 col4" >1.52</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_25203 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_25203" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25203_level0_col0" class="col_heading level0 col0" >actual</th>
#       <th id="T_25203_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_25203_level0_col2" class="col_heading level0 col2" >abs_acc</th>
#       <th id="T_25203_level0_col3" class="col_heading level0 col3" >rel_acc</th>
#       <th id="T_25203_level0_col4" class="col_heading level0 col4" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25203_level0_row0" class="row_heading level0 row0" >140155</th>
#       <td id="T_25203_row0_col0" class="data row0 col0" >44,057.00</td>
#       <td id="T_25203_row0_col1" class="data row0 col1" >43,041.49</td>
#       <td id="T_25203_row0_col2" class="data row0 col2" >97.64</td>
#       <td id="T_25203_row0_col3" class="data row0 col3" >96.41</td>
#       <td id="T_25203_row0_col4" class="data row0 col4" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_25203_level0_row1" class="row_heading level0 row1" >140156</th>
#       <td id="T_25203_row1_col0" class="data row1 col0" >43,256.00</td>
#       <td id="T_25203_row1_col1" class="data row1 col1" >42,830.41</td>
#       <td id="T_25203_row1_col2" class="data row1 col2" >99.01</td>
#       <td id="T_25203_row1_col3" class="data row1 col3" >98.50</td>
#       <td id="T_25203_row1_col4" class="data row1 col4" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_25203_level0_row2" class="row_heading level0 row2" >140157</th>
#       <td id="T_25203_row2_col0" class="data row2 col0" >41,552.00</td>
#       <td id="T_25203_row2_col1" class="data row2 col1" >41,208.59</td>
#       <td id="T_25203_row2_col2" class="data row2 col2" >99.17</td>
#       <td id="T_25203_row2_col3" class="data row2 col3" >98.79</td>
#       <td id="T_25203_row2_col4" class="data row2 col4" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_25203_level0_row3" class="row_heading level0 row3" >140158</th>
#       <td id="T_25203_row3_col0" class="data row3 col0" >38,500.00</td>
#       <td id="T_25203_row3_col1" class="data row3 col1" >38,554.85</td>
#       <td id="T_25203_row3_col2" class="data row3 col2" >99.86</td>
#       <td id="T_25203_row3_col3" class="data row3 col3" >99.81</td>
#       <td id="T_25203_row3_col4" class="data row3 col4" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_25203_level0_row4" class="row_heading level0 row4" >140159</th>
#       <td id="T_25203_row4_col0" class="data row4 col0" >35,486.00</td>
#       <td id="T_25203_row4_col1" class="data row4 col1" >31,734.80</td>
#       <td id="T_25203_row4_col2" class="data row4 col2" >88.18</td>
#       <td id="T_25203_row4_col3" class="data row4 col3" >86.75</td>
#       <td id="T_25203_row4_col4" class="data row4 col4" >0.69</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**Cross-Validation Results with Lag Features**

# %%
cross_results_lags, rmses_lags = cross_validation_train(df,
									   target_column = "PJME_MW",
									   lags = True,
									   lag_label_list = lag_label_list,
									   learning_rate = 0.012, 
									   verbose = 500,
									   splits = 16)
# Out:
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  1 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:31723.90046	validation_1-rmse:32036.34632
# [217]	validation_0-rmse:3647.14382	validation_1-rmse:6509.72283
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  2 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:31945.88388	validation_1-rmse:32435.43757
# [500]	validation_0-rmse:2700.04290	validation_1-rmse:3213.83792
# [745]	validation_0-rmse:2507.44853	validation_1-rmse:3186.89497
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  3 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32132.81808	validation_1-rmse:32786.99460
# [500]	validation_0-rmse:2852.29457	validation_1-rmse:3586.01348
# [607]	validation_0-rmse:2771.12645	validation_1-rmse:3574.18077
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  4 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32310.12357	validation_1-rmse:33464.70094
# [500]	validation_0-rmse:3010.00525	validation_1-rmse:3463.71019
# [1000]	validation_0-rmse:2760.07384	validation_1-rmse:3369.62773
# [1016]	validation_0-rmse:2754.67345	validation_1-rmse:3370.59850
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  5 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32562.88581	validation_1-rmse:33065.57523
# [378]	validation_0-rmse:3198.38094	validation_1-rmse:3425.38733
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  6 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32657.57497	validation_1-rmse:33670.71126
# [500]	validation_0-rmse:3121.68247	validation_1-rmse:3431.29513
# [505]	validation_0-rmse:3118.39112	validation_1-rmse:3431.96235
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  7 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32816.81045	validation_1-rmse:32177.20903
# [294]	validation_0-rmse:3478.93444	validation_1-rmse:3338.82832
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  8 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32734.68986	validation_1-rmse:33070.69103
# [416]	validation_0-rmse:3232.16670	validation_1-rmse:3968.47546
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  9 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32773.24437	validation_1-rmse:33321.74997
# [500]	validation_0-rmse:3205.99135	validation_1-rmse:3218.68143
# [590]	validation_0-rmse:3146.14405	validation_1-rmse:3217.26784
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  10 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32831.49327	validation_1-rmse:31628.32411
# [319]	validation_0-rmse:3476.79944	validation_1-rmse:3169.49419
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  11 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32720.23175	validation_1-rmse:32058.20328
# [500]	validation_0-rmse:3245.43535	validation_1-rmse:3299.96903
# [632]	validation_0-rmse:3183.53262	validation_1-rmse:3297.91681
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  12 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32667.13787	validation_1-rmse:31892.19522
# [390]	validation_0-rmse:3338.51825	validation_1-rmse:3767.45289
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  13 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32606.94175	validation_1-rmse:32074.44497
# [500]	validation_0-rmse:3298.54113	validation_1-rmse:3486.46383
# [707]	validation_0-rmse:3206.08220	validation_1-rmse:3435.60003
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  14 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32566.06900	validation_1-rmse:31008.53148
# [350]	validation_0-rmse:3457.43004	validation_1-rmse:3502.56760
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  15 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32463.55417	validation_1-rmse:31412.30388
# [500]	validation_0-rmse:3321.05982	validation_1-rmse:4105.53720
# [672]	validation_0-rmse:3246.16523	validation_1-rmse:4076.88926
# <span style = 'line-height: 2;                                 background: #444444; width: None;                                 border: 1px solid text_color;                                border-radius: 0px; text-align: center;                                padding: 5px;'>                                <b><font size=3><text style=color:white>Training round:  16 / 16                                </text></font></b></style>
# [0]	validation_0-rmse:32397.32826	validation_1-rmse:31400.60420
# [369]	validation_0-rmse:3474.27652	validation_1-rmse:4006.44573
# <span style = 'display: block; width: 500.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>Overall Metrics for Accuracy and Model Performance						</text></font></b></style>
# <center><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Resulting Metrics</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Average RMSE</th>
#       <td>3,728.29</td>
#     </tr>
#     <tr>
#       <th>Average Absolute Accuracy</th>
#       <td>91.60%</td>
#     </tr>
#     <tr>
#       <th>Average Relative Accuracy</th>
#       <td>91.51%</td>
#     </tr>
#     <tr>
#       <th>Average Sharpe Ratio</th>
#       <td>0.48</td>
#     </tr>
#   </tbody>
# </table>
# <span style = 'display: block; width: 290.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>Predictions vs Actual Targets						</text></font></b></style>
# <center><style type="text/css">
# #T_16438 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_16438" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16438_level0_col0" class="col_heading level0 col0" >actual</th>
#       <th id="T_16438_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_16438_level0_col2" class="col_heading level0 col2" >abs_acc</th>
#       <th id="T_16438_level0_col3" class="col_heading level0 col3" >rel_acc</th>
#       <th id="T_16438_level0_col4" class="col_heading level0 col4" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16438_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16438_row0_col0" class="data row0 col0" >48,920.00</td>
#       <td id="T_16438_row0_col1" class="data row0 col1" >43,241.39</td>
#       <td id="T_16438_row0_col2" class="data row0 col2" >86.87</td>
#       <td id="T_16438_row0_col3" class="data row0 col3" >82.15</td>
#       <td id="T_16438_row0_col4" class="data row0 col4" >1.01</td>
#     </tr>
#     <tr>
#       <th id="T_16438_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16438_row1_col0" class="data row1 col0" >50,389.00</td>
#       <td id="T_16438_row1_col1" class="data row1 col1" >43,278.83</td>
#       <td id="T_16438_row1_col2" class="data row1 col2" >83.57</td>
#       <td id="T_16438_row1_col3" class="data row1 col3" >77.66</td>
#       <td id="T_16438_row1_col4" class="data row1 col4" >1.26</td>
#     </tr>
#     <tr>
#       <th id="T_16438_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16438_row2_col0" class="data row2 col0" >51,295.00</td>
#       <td id="T_16438_row2_col1" class="data row2 col1" >43,278.83</td>
#       <td id="T_16438_row2_col2" class="data row2 col2" >81.48</td>
#       <td id="T_16438_row2_col3" class="data row2 col3" >74.81</td>
#       <td id="T_16438_row2_col4" class="data row2 col4" >1.42</td>
#     </tr>
#     <tr>
#       <th id="T_16438_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16438_row3_col0" class="data row3 col0" >51,623.00</td>
#       <td id="T_16438_row3_col1" class="data row3 col1" >43,278.83</td>
#       <td id="T_16438_row3_col2" class="data row3 col2" >80.72</td>
#       <td id="T_16438_row3_col3" class="data row3 col3" >73.78</td>
#       <td id="T_16438_row3_col4" class="data row3 col4" >1.48</td>
#     </tr>
#     <tr>
#       <th id="T_16438_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16438_row4_col0" class="data row4 col0" >51,517.00</td>
#       <td id="T_16438_row4_col1" class="data row4 col1" >43,278.83</td>
#       <td id="T_16438_row4_col2" class="data row4 col2" >80.96</td>
#       <td id="T_16438_row4_col3" class="data row4 col3" >74.11</td>
#       <td id="T_16438_row4_col4" class="data row4 col4" >1.46</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_84985 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_84985" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84985_level0_col0" class="col_heading level0 col0" >actual</th>
#       <th id="T_84985_level0_col1" class="col_heading level0 col1" >prediction</th>
#       <th id="T_84985_level0_col2" class="col_heading level0 col2" >abs_acc</th>
#       <th id="T_84985_level0_col3" class="col_heading level0 col3" >rel_acc</th>
#       <th id="T_84985_level0_col4" class="col_heading level0 col4" >sharpe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84985_level0_row0" class="row_heading level0 row0" >140155</th>
#       <td id="T_84985_row0_col0" class="data row0 col0" >44,057.00</td>
#       <td id="T_84985_row0_col1" class="data row0 col1" >40,874.35</td>
#       <td id="T_84985_row0_col2" class="data row0 col2" >92.21</td>
#       <td id="T_84985_row0_col3" class="data row0 col3" >90.00</td>
#       <td id="T_84985_row0_col4" class="data row0 col4" >0.56</td>
#     </tr>
#     <tr>
#       <th id="T_84985_level0_row1" class="row_heading level0 row1" >140156</th>
#       <td id="T_84985_row1_col0" class="data row1 col0" >43,256.00</td>
#       <td id="T_84985_row1_col1" class="data row1 col1" >39,856.94</td>
#       <td id="T_84985_row1_col2" class="data row1 col2" >91.47</td>
#       <td id="T_84985_row1_col3" class="data row1 col3" >89.32</td>
#       <td id="T_84985_row1_col4" class="data row1 col4" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_84985_level0_row2" class="row_heading level0 row2" >140157</th>
#       <td id="T_84985_row2_col0" class="data row2 col0" >41,552.00</td>
#       <td id="T_84985_row2_col1" class="data row2 col1" >38,255.34</td>
#       <td id="T_84985_row2_col2" class="data row2 col2" >91.38</td>
#       <td id="T_84985_row2_col3" class="data row2 col3" >89.64</td>
#       <td id="T_84985_row2_col4" class="data row2 col4" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_84985_level0_row3" class="row_heading level0 row3" >140158</th>
#       <td id="T_84985_row3_col0" class="data row3 col0" >38,500.00</td>
#       <td id="T_84985_row3_col1" class="data row3 col1" >36,084.84</td>
#       <td id="T_84985_row3_col2" class="data row3 col2" >93.31</td>
#       <td id="T_84985_row3_col3" class="data row3 col3" >92.41</td>
#       <td id="T_84985_row3_col4" class="data row3 col4" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_84985_level0_row4" class="row_heading level0 row4" >140159</th>
#       <td id="T_84985_row4_col0" class="data row4 col0" >35,486.00</td>
#       <td id="T_84985_row4_col1" class="data row4 col1" >30,279.28</td>
#       <td id="T_84985_row4_col2" class="data row4 col2" >82.80</td>
#       <td id="T_84985_row4_col3" class="data row4 col3" >83.64</td>
#       <td id="T_84985_row4_col4" class="data row4 col4" >0.92</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;

# %% [markdown]
# <a name="future_predictions"></a>
#
# ---
#
# **Sections:**  ●  [Top](#top)  ●  [The Data](#data)  ●  [Removing Outliers](#outliers)  ●  [Feature Engineering](#features)  ●  [Investigating Correlation](#correlation)   ●  [Lag Features](#lag_features)   ●  [Splitting](#splitting)   ●  [The Model](#model)   ●  [Results with Traditional Split](#traditional_results)   ●  [Using Cross-Validation](#cross_validation)   ●  [Making Future Predictions](#future_predictions)
#
# ---
#
# <span style = 'background-color: purple; padding: 5px 5px 3px 5px; line-height: 1.5; color:white;border-radius: 3px;'><font size = 4>**Predicting into the Future**</font></span>

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**1. Retrain Model with All Training Data**

# %%
df = data.query('PJME_MW > 18_500').copy()

# %%
def future_predicting_model(df, target_column, 
						   lags = False, 
						   lag_label_list = None, 
						   base_score = 0.5,
						   booster = 'gbtree',
						   n_estimators = 500,
						   early_stopping_rounds = 50,
						   objective = 'reg:squarederror',
						   max_depth = 3,
						   learning_rate = 0.012, 
						   verbose = 250):
	
	from sklearn.metrics import mean_squared_error
	from sklearn.model_selection import TimeSeriesSplit
	
	# ................ Establishing Features & Targets ................ #
	
	df = featurize_datetime_index(df)
	target = target_column
	
	# ................ Lag Features & Feature Cleanup ................. #

	if lags:
		df = year_lags(df, target_column, lag_label_list)
		features = list(df.columns)
		features.remove('weekday_name')
		features.remove('month_name')
		features.remove('time_of_day')
		features.remove(target)
	else:
		features = list(df.columns)
		features.remove('weekday_name')
		features.remove('month_name')
		features.remove('time_of_day')
		features.remove(target)
		
	# ................. Correcting Datatypes for Model ................ #
		
	df['week_of_year'] = df.week_of_year.astype(float)
	
	input_data = df[features]
	target_data = df[target_column]
	
	model = XGBRegressor(base_score = base_score,
					   booster = booster,
					   n_estimators = n_estimators,
					   early_stopping_rounds = early_stopping_rounds,
					   objective = objective,
					   max_depth = max_depth,
					   learning_rate = learning_rate)
	
	trained_model = model.fit(input_data, target_data,
							 eval_set = [(input_data, target_data)],
							 verbose = verbose)
	
	return trained_model

# %%
trained_model = future_predicting_model(df, 
										'PJME_MW', 
										lags = True,
									    lag_label_list = lag_label_list)
# Out:
# [0]	validation_0-rmse:32339.29917
# [250]	validation_0-rmse:3964.45913
# [499]	validation_0-rmse:3400.52671

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**2. Create an empty dataframe for the date range to predict**
# * Starting from the end of the input data
# * Predicting almost 1 year into the future
# * Frequency will be 1 hour, just like the input data frequency

# %%
df.index.max()
# Out:
# Timestamp('2018-08-03 00:00:00')

# %%
prediction_range = pd.date_range('2018-08-03', '2019-08-01',
								freq = '1h')

see(prediction_range[0:6], "First rows of prediction df")
# Out:
# <span style = 'display: block; width: 270.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>First rows of prediction df						</text></font></b></style>
# <center><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2018-08-03 00:00:00</th>
#       <td>2018-08-03 00:00:00</td>
#     </tr>
#     <tr>
#       <th>2018-08-03 01:00:00</th>
#       <td>2018-08-03 01:00:00</td>
#     </tr>
#     <tr>
#       <th>2018-08-03 02:00:00</th>
#       <td>2018-08-03 02:00:00</td>
#     </tr>
#     <tr>
#       <th>2018-08-03 03:00:00</th>
#       <td>2018-08-03 03:00:00</td>
#     </tr>
#     <tr>
#       <th>2018-08-03 04:00:00</th>
#       <td>2018-08-03 04:00:00</td>
#     </tr>
#     <tr>
#       <th>2018-08-03 05:00:00</th>
#       <td>2018-08-03 05:00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
future_predictions_df = pd.DataFrame(index = prediction_range)
future_predictions_df['in_future'] = True
orig = df.copy()
orig['in_future'] = False
orig_plus_future = pd.concat([orig, future_predictions_df])

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**3. Combining the Past Data with Future**
# * Adding the datetime and lag features
# * Pulling out just the records that need predictions, `future_predictions`
# * Removing from features the columns the model cannot or should not work with

# %%
orig_plus_future = featurize_datetime_index(orig_plus_future)
orig_plus_future = year_lags(orig_plus_future, 
							 target_column = "PJME_MW", 
							 lag_label_list = lag_label_list)

# %%
features = list(orig_plus_future.columns)
features.remove('weekday_name')
features.remove('month_name')
features.remove('time_of_day')
features.remove('PJME_MW')
features.remove('in_future')

# %%
future_predictions = orig_plus_future.query('in_future').copy()
head_tail_horz(future_predictions, 5, 'DF for Future Predictions')
# Out:
# <span style = 'display: block; width: 250.0px; 						line-height: 2; background: #333333;						margin-left: auto; margin-right: auto;						border: 1px solid text_color;						border-radius: 3px; text-align: center;						padding: 3px 8px 3px 8px;'>						<b><font size=4><text style=color:white>DF for Future Predictions						</text></font></b></style>
# <center><style type="text/css">
# #T_1e682 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_1e682" style='display:inline-block'>
#   <caption>head(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e682_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_1e682_level0_col1" class="col_heading level0 col1" >in_future</th>
#       <th id="T_1e682_level0_col2" class="col_heading level0 col2" >hour</th>
#       <th id="T_1e682_level0_col3" class="col_heading level0 col3" >weekday</th>
#       <th id="T_1e682_level0_col4" class="col_heading level0 col4" >weekday_name</th>
#       <th id="T_1e682_level0_col5" class="col_heading level0 col5" >month</th>
#       <th id="T_1e682_level0_col6" class="col_heading level0 col6" >month_name</th>
#       <th id="T_1e682_level0_col7" class="col_heading level0 col7" >quarter</th>
#       <th id="T_1e682_level0_col8" class="col_heading level0 col8" >year</th>
#       <th id="T_1e682_level0_col9" class="col_heading level0 col9" >week_of_year</th>
#       <th id="T_1e682_level0_col10" class="col_heading level0 col10" >day_of_year</th>
#       <th id="T_1e682_level0_col11" class="col_heading level0 col11" >time_of_day</th>
#       <th id="T_1e682_level0_col12" class="col_heading level0 col12" >one_year</th>
#       <th id="T_1e682_level0_col13" class="col_heading level0 col13" >two_year</th>
#       <th id="T_1e682_level0_col14" class="col_heading level0 col14" >three_year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e682_level0_row0" class="row_heading level0 row0" >2018-08-03</th>
#       <td id="T_1e682_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_1e682_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_1e682_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1e682_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_1e682_row0_col4" class="data row0 col4" >Friday</td>
#       <td id="T_1e682_row0_col5" class="data row0 col5" >8</td>
#       <td id="T_1e682_row0_col6" class="data row0 col6" >August</td>
#       <td id="T_1e682_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_1e682_row0_col8" class="data row0 col8" >2,018</td>
#       <td id="T_1e682_row0_col9" class="data row0 col9" >31</td>
#       <td id="T_1e682_row0_col10" class="data row0 col10" >215</td>
#       <td id="T_1e682_row0_col11" class="data row0 col11" >midnight</td>
#       <td id="T_1e682_row0_col12" class="data row0 col12" >33,539.00</td>
#       <td id="T_1e682_row0_col13" class="data row0 col13" >32,094.00</td>
#       <td id="T_1e682_row0_col14" class="data row0 col14" >31,695.00</td>
#     </tr>
#     <tr>
#       <th id="T_1e682_level0_row1" class="row_heading level0 row1" >2018-08-03</th>
#       <td id="T_1e682_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_1e682_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_1e682_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_1e682_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_1e682_row1_col4" class="data row1 col4" >Friday</td>
#       <td id="T_1e682_row1_col5" class="data row1 col5" >8</td>
#       <td id="T_1e682_row1_col6" class="data row1 col6" >August</td>
#       <td id="T_1e682_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_1e682_row1_col8" class="data row1 col8" >2,018</td>
#       <td id="T_1e682_row1_col9" class="data row1 col9" >31</td>
#       <td id="T_1e682_row1_col10" class="data row1 col10" >215</td>
#       <td id="T_1e682_row1_col11" class="data row1 col11" >midnight</td>
#       <td id="T_1e682_row1_col12" class="data row1 col12" >30,781.00</td>
#       <td id="T_1e682_row1_col13" class="data row1 col13" >29,503.00</td>
#       <td id="T_1e682_row1_col14" class="data row1 col14" >29,128.00</td>
#     </tr>
#     <tr>
#       <th id="T_1e682_level0_row2" class="row_heading level0 row2" >2018-08-03</th>
#       <td id="T_1e682_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_1e682_row2_col1" class="data row2 col1" >True</td>
#       <td id="T_1e682_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_1e682_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_1e682_row2_col4" class="data row2 col4" >Friday</td>
#       <td id="T_1e682_row2_col5" class="data row2 col5" >8</td>
#       <td id="T_1e682_row2_col6" class="data row2 col6" >August</td>
#       <td id="T_1e682_row2_col7" class="data row2 col7" >3</td>
#       <td id="T_1e682_row2_col8" class="data row2 col8" >2,018</td>
#       <td id="T_1e682_row2_col9" class="data row2 col9" >31</td>
#       <td id="T_1e682_row2_col10" class="data row2 col10" >215</td>
#       <td id="T_1e682_row2_col11" class="data row2 col11" >midnight</td>
#       <td id="T_1e682_row2_col12" class="data row2 col12" >29,015.00</td>
#       <td id="T_1e682_row2_col13" class="data row2 col13" >27,712.00</td>
#       <td id="T_1e682_row2_col14" class="data row2 col14" >27,373.00</td>
#     </tr>
#     <tr>
#       <th id="T_1e682_level0_row3" class="row_heading level0 row3" >2018-08-03</th>
#       <td id="T_1e682_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_1e682_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_1e682_row3_col2" class="data row3 col2" >3</td>
#       <td id="T_1e682_row3_col3" class="data row3 col3" >4</td>
#       <td id="T_1e682_row3_col4" class="data row3 col4" >Friday</td>
#       <td id="T_1e682_row3_col5" class="data row3 col5" >8</td>
#       <td id="T_1e682_row3_col6" class="data row3 col6" >August</td>
#       <td id="T_1e682_row3_col7" class="data row3 col7" >3</td>
#       <td id="T_1e682_row3_col8" class="data row3 col8" >2,018</td>
#       <td id="T_1e682_row3_col9" class="data row3 col9" >31</td>
#       <td id="T_1e682_row3_col10" class="data row3 col10" >215</td>
#       <td id="T_1e682_row3_col11" class="data row3 col11" >midnight</td>
#       <td id="T_1e682_row3_col12" class="data row3 col12" >27,884.00</td>
#       <td id="T_1e682_row3_col13" class="data row3 col13" >26,535.00</td>
#       <td id="T_1e682_row3_col14" class="data row3 col14" >26,233.00</td>
#     </tr>
#     <tr>
#       <th id="T_1e682_level0_row4" class="row_heading level0 row4" >2018-08-03</th>
#       <td id="T_1e682_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_1e682_row4_col1" class="data row4 col1" >True</td>
#       <td id="T_1e682_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_1e682_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_1e682_row4_col4" class="data row4 col4" >Friday</td>
#       <td id="T_1e682_row4_col5" class="data row4 col5" >8</td>
#       <td id="T_1e682_row4_col6" class="data row4 col6" >August</td>
#       <td id="T_1e682_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_1e682_row4_col8" class="data row4 col8" >2,018</td>
#       <td id="T_1e682_row4_col9" class="data row4 col9" >31</td>
#       <td id="T_1e682_row4_col10" class="data row4 col10" >215</td>
#       <td id="T_1e682_row4_col11" class="data row4 col11" >midnight</td>
#       <td id="T_1e682_row4_col12" class="data row4 col12" >27,223.00</td>
#       <td id="T_1e682_row4_col13" class="data row4 col13" >25,870.00</td>
#       <td id="T_1e682_row4_col14" class="data row4 col14" >25,643.00</td>
#     </tr>
#   </tbody>
# </table>
# &nbsp;&nbsp;&nbsp;<style type="text/css">
# #T_1ce36 caption {
#   background: #333333;
#   border-radius: 3px;
#   padding: 5px;
#   color: white;
#   font-size: 12px;
#   font-weight: bold;
# }
# </style>
# <table id="T_1ce36" style='display:inline-block'>
#   <caption>tail(5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ce36_level0_col0" class="col_heading level0 col0" >PJME_MW</th>
#       <th id="T_1ce36_level0_col1" class="col_heading level0 col1" >in_future</th>
#       <th id="T_1ce36_level0_col2" class="col_heading level0 col2" >hour</th>
#       <th id="T_1ce36_level0_col3" class="col_heading level0 col3" >weekday</th>
#       <th id="T_1ce36_level0_col4" class="col_heading level0 col4" >weekday_name</th>
#       <th id=

# %%
future_predictions = future_predictions[features]
future_predictions['week_of_year'] = future_predictions['week_of_year'].astype(float)

# %%
future_predictions['predictions'] = trained_model.predict(future_predictions[features])

# %% [markdown]
# <font size = 4><span style = 'background-color: #ddddff; padding: 5px 5px 3px 5px; line-height: 1.5; color:black;border-radius: 3px;'>**4. Plotting the Prediction Results**

# %%
plt.figure(figsize = (13, 7), facecolor = '#333333')
ax = plt.axes()
future_predictions['predictions'].plot(ax = ax, color = 'cyan')
ax.set_facecolor('#444444')
plt.legend();
ax.grid()
plt.xlabel('', color = 'white', fontsize = 15)
plt.ylabel('energy usage', color = 'white', fontsize = 15)
plt.tick_params(labelcolor = 'white', which = 'both')
plt.title('Future Predictions', 
		  fontsize = 20, pad = 20, color = 'white');
plt.legend().remove()
